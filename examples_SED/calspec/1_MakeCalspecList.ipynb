# %% [markdown]
# # Build a list of Calspec Star for AuxTel
#
# - author : Sylvie Dagoret-Campagne
# - affliliation : CNRS
# - creation date : 25/09/2019
# - Update : October 8th 2019
# - Update : April 20th 2020 for package PhotomCorrectAuxTel
#
#
# From Pysynphot, il get all CALSPEC filenames. It extract HD type stars, get their Ra Dec and filename and make a summary file of all the CALSPEC available

# %%
import os
import re
import numpy as np
from math import ceil,floor

# %%
import pysynphot as S

# %%
import locale
locale.setlocale(locale.LC_ALL,'en_US.UTF-8') # vary depending on your lang/locale
# Out:
# 'en_US.UTF-8'

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import time
from datetime import datetime,date
import dateutil.parser
import astropy.units as u
from astropy.time import Time
from astropy.coordinates import SkyCoord, EarthLocation, AltAz
from astropy.coordinates import Angle
from astropy import units as u
import astropy.coordinates as coord

# %%
from astropy.io import fits
from astropy.table import Table
from astropy.time import Time
import astropy
from astropy.visualization.mpl_normalize import (ImageNormalize,MinMaxInterval,PercentileInterval,SqrtStretch,LogStretch)
from astropy.visualization.wcsaxes import SphericalCircle

# %%
from astroquery.simbad import Simbad

# %%
pysynphot_root_path=os.environ['PYSYN_CDBS']

# %%
pysynphot_root_path
# Out:
# '/Users/dagoret/MacOSX/External/PySynPhotData/grp/hst/cdbs'

# %%
path_sed_calspec=os.path.join(pysynphot_root_path,'calspec')

# %%
def GetListOfFiles(thedir,tag):
    """
    - thedir : directory where are the files
    - tage  = the re expression to file the filename with regular expression
    """
    all_files=os.listdir(thedir)
    sorted_files=sorted(all_files)
    selected_files=[]
    for sfile in sorted_files:
        if re.search(tag,sfile):
            selected_files.append(sfile)
    return selected_files

# %%
def FilterListOfFiles(listOfFiles):
    """
    Filter list of files   
    """
    
    all_selected_files=[]
    
    current_root_fn=None  # root of filename ex hd000000
    current_fn=None    # filename of calspec ex hd000000_stis.fits
    
    for fn in listOfFiles:
        
        root_fn=fn.split("_")[0]
        
        if current_root_fn==None:
            current_root_fn=root_fn
            current_fn=fn
            continue
            
        if root_fn != current_root_fn:
            all_selected_files.append(current_fn)
            
        current_fn=fn
        current_root_fn=root_fn

    return all_selected_files

# %%
# the tag to find the good filename
RETAGFNNAME=".*fits$"
#RETAGFNNAME="^hd.*_stis_[0-9][0-9][0-9].fits$"
#RETAGDRNAME="(^T1M_.*_HD116405_Filtre_None)_bin1x1.*_red.fit$"

# %%
all_files=os.listdir(path_sed_calspec)

# %%
all_files=sorted(all_files)

# %%
print(all_files)
# Out:
# ['10lac_mod_001.fits', '10lac_mod_002.fits', '10lac_stis_001.fits', '10lac_stis_002.fits', '10lac_stis_003.fits', '10lac_stis_004.fits', '1732526_mod_001.fits', '1732526_mod_002.fits', '1732526_nic_002.fits', '1732526_stisnic_001.fits', '1732526_stisnic_002.fits', '1732526_stisnic_003.fits', '1732526_stisnic_004.fits', '1740346_nic_001.fits', '1740346_nic_002.fits', '1740346_stisnic_001.fits', '1740346_stisnic_002.fits', '1740346_stisnic_003.fits', '1743045_mod_001.fits', '1743045_mod_002.fits', '1743045_nic_001.fits', '1743045_nic_002.fits', '1743045_stisnic_001.fits', '1743045_stisnic_002.fits', '1743
# ['10lac_stis_004.fits', '1732526_stisnic_004.fits', '1740346_stisnic_003.fits', '1743045_stisnic_004.fits', '1757132_stis_004.fits', '1802271_stisnic_004.fits', '1805292_stisnic_004.fits', '1808347_stis_004.fits', '1812095_stisnic_004.fits', '1812524_nic_004.fits', '2m003618_stisnic_006.fits', '2m055914_stisnic_006.fits', 'WDcovar_001.fits', 'agk_81d266_stisnic_006.fits', 'alpha_lyr_stis_008.fits', 'bd02d3375_stis_003.fits', 'bd17d4708_stisnic_001.fits', 'bd21d0607_stis_003.fits', 'bd26d2606_stis_003.fits', 'bd29d2091_stis_003.fits', 'bd54d1216_stis_003.fits', 'bd60d1753_stis_004.fits', 'bd_75d325_stis_004.fits', 'c26202_stisnic_007.fits', 'etauma_stis_003.fits', 'feige110_stisnic_006.fits', 'feige34_stis_004.fits', 'feige66_002.fits', 'feige67_002.fits', 'g191b2b_stisnic_006.fits', 'g93_48_004.fits', 'gd108_005.fits', 'gd153_stisnic_006.fits', 'gd50_004.fits', 'gd71_stisnic_006.fits', 'gj7541a_stis_003.fits', 'grw_70d5824_stisnic_007.fits', 'hd009051_stis_003.fits', 'hd031128_stis_003.fits', 'hd074000_stis_003.fits', 'hd106252_stis_004.fits', 'hd111980_stis_003.fits', 'hd116405_stis_004.fits', 'hd14943_stis_004.fits', 'hd158485_stis_004.fits', 'hd159222_stis_004.fits', 'hd160617_stis_003.fits', 'hd163466_stis_004.fits', 'hd165459_stisnic_004.fits', 'hd180609_stis_004.fits', 'hd185975_stis_003.fits', 'hd200654_stis_003.fits', 'hd205905_stis_004.fits', 'hd209458_stisnic_007.fits', 'hd37725_stis_004.fits', 'hd37962_stis_004.fits', 'hd38949_stis_004.fits', 'hd60753_stis_003.fits', 'hd93521_stis_004.fits', 'hs2027_stis_004.fits', 'hz21_stis_004.fits', 'hz2_005.fits', 'hz43_stis_004.fits', 'hz43b_stis_004.fits', 'hz44_stis_004.fits', 'hz4_stis_005.fits', 'kf01t5_nic_003.fits', 'kf06t1_nic_003.fits', 'kf06t2_stisnic_004.fits', 'kf08t3_stisnic_001.fits', 'ksi2ceti_stis_004.fits', 'lamlep_stis_004.fits', 'lb227_004.fits', 'lds749b_stisnic_006.fits', 'ltt9491_002.fits', 'mucol_stis_004.fits', 'ngc7293_005.fits', 'p041c_stisnic_007.fits', 'p177d_stisnic_007.fits', 'p330e_stisnic_008.fits', 'sf1615001a_stisnic_001.fits', 'sf1615_001a_stisnic_007.fits', 'sirius_stis_002.fits', 'snap1_stisnic_006.fits', 'snap2_stisnic_007.fits', 'sun_reference_stis_002.fits', 'vb8_stisnic_006.fits', 'wd0308_565_stis_004.fits', 'wd0320_539_stis_004.fits', 'wd0947_857_stis_004.fits', 'wd1026_453_stis_004.fits', 'wd1057_719_stisnic_006.fits']

# %%
Simbad.list_votable_fields()
# Out:
# --NOTES--
#
# 1. The parameter filtername must correspond to an existing filter. Filters include: B,V,R,I,J,K.  They are checked by SIMBAD but not astroquery.simbad
#
# 2. Fields beginning with rvz display the data as it is in the database. Fields beginning with rv force the display as a radial velocity. Fields beginning with z force the display as a redshift
#
# 3. For each measurement catalog, the VOTable contains all fields of the first measurement. When applicable, the first measurement is the mean one.
#
# Available VOTABLE fields:
#
# bibcodelist(y1-y2)
# biblio
# cel
# cl.g
# coo(opt)
# coo_bibcode
# coo_err_angle
# coo_err_maja
# coo_err_mina
# coo_qual
# coo_wavelength
# coordinates
# dec(opt)
# dec_prec
# diameter
# dim
# dim_angle
# dim_bibcode
# dim_incl
# dim_majaxis
# dim_minaxis
# dim_qual
# dim_wavelength
# dimensions
# distance
# distance_result
# einstein
# fe_h
# flux(filtername)
# flux_bibcode(filtername)
# flux_error(filtername)
# flux_name(filtername)
# flux_qual(filtername)
# flux_system(filtername)
# flux_unit(filtername)
# fluxdata(filtername)
# gcrv
# gen
# gj
# hbet
# hbet1
# hgam
# id(opt)
# ids
# iras
# irc
# iso
# iue
# jp11
# link_bibcode
# main_id
# measurements
# membership
# mesplx
# mespm
# mk
# morphtype
# mt
# mt_bibcode
# mt_qual
# otype
# otype(opt)
# otypes
# parallax
# plx
# plx_bibcode
# plx_error
# plx_prec
# plx_qual
# pm
# pm_bibcode
# pm_err_angle
# pm_err_maja
# pm_err_mina
# pm_qual
# pmdec
# pmdec_prec
# pmra
# pmra_prec
# pos
# posa
# propermotions
# ra(opt)
# ra_prec
# rot
# rv_value
# rvz_bibcode
# rvz_error
# rvz_qual
# rvz_radvel
# rvz_type
# rvz_wavelength
# sao
# sp
# sp_bibcode
# sp_nature
# sp_qual
# sptype
# td1
# typed_id
# ubv
# uvby
# uvby1
# v*
# velocity
# xmm
# z_value
# For more information on a field:
# Simbad.get_field_description ('field_name')
# Currently active VOTABLE fields:
#  ['main_id', 'coordinates']

# %%
Simbad.add_votable_fields('sptype')
Simbad.add_votable_fields('flux(U)') # add the Vega unit Magnitude 
Simbad.add_votable_fields('flux(B)') # add the Vega unit Magnitude 
Simbad.add_votable_fields('flux(V)') # add the Vega unit Magnitude 
Simbad.add_votable_fields('flux(R)') # add the Vega unit Magnitude 
Simbad.add_votable_fields('flux(I)') # add the Vega unit Magnitude 
#Simbad.add_votable_fields('flux_unit(V)')
#Simbad.add_votable_fields('flux_unit(I)')
#Simbad.add_votable_fields('flux_system(V)')
#Simbad.add_votable_fields('flux_system(I)')
#Simbad.add_votable_fields('ubv')  # Johnson UBV system

# %%
Simbad.get_field_description("otype")
# Out:
# standard name of the object type

# %%
Simbad.get_field_description("ubv")
# Out:
# UBV data in Johnson's UBV system
#               compiled by J.-Cl. Mermilliod from Institut d Astronomie de Lausanne (1973A&AS...71..413M)

# %%
Simbad.get_field_description("uvby")
# Out:
# The Strömgren uvby photometric system

# %%
all_tables=[]
all_objnames=[]
all_ra=[]
all_dec=[]
all_sp_type=[]
all_sp_qual=[]
all_mag_U=[]
all_mag_B=[]
all_mag_V=[]
all_mag_R=[]
all_mag_I=[]

all_goodcalspecfile=[]

for file in all_selected_calspec:
    fullfilename=os.path.join(path_sed_calspec,file)
    
    hdu = fits.open(fullfilename)
    img=hdu[0].data
    hd=hdu[0].header
    
    print(file)
    
    if file in ["WDcovar_001.fits"]:
        print(">>>>> SKIP file {} ".format(file))
        continue
    
    OBJNAME=hd["TARGETID"]
    print("==============",OBJNAME,"===========================")
    
    if OBJNAME in ["1732526","1740346","1743045","1757132","1802271","1805292","1808347","1812095","1812524","2M0036+18","2M0559-14","AGK+81D266",
                   "BD02D3375","BD17D4708","BD21D0607","BD26D2606","BD29D2091","BD54D1216","BD60D1753","BD75","C26202","ETAUMA","GJ7541A","GRW+70D5824","HS2027","KF01T5",
                  "KF06T1","KF06T2","KF08T3","KSI2CETI","LAMLEP","MUCOL","P041C","P177D","P330E","SF1615001A","SF1615+001A","SNAP-1","SNAP-2","SUN_REFERENCE","WD0947_857","WD1026_453",
                   "HZ43B","WD0320-539","VB8"]:
        print(">>>>> SKIP TARGET {} ".format(OBJNAME))
        continue
        
    result_table = Simbad.query_object(OBJNAME)
    
    
    if len(result_table)==0:
        print(">>>>> TARGET {} not found in Simbad".format(OBJNAME))
        continue
        
    
           
    result_table.pprint(show_unit=True, max_width=80)
    
    ra = coord.Angle(result_table["RA"], unit=u.hour) # create an Angle object
    dec = coord.Angle(result_table["DEC"], unit=u.deg) # create an Angle object
    skycoord=SkyCoord(ra=ra,dec=dec)[0]
    
    thetype=result_table["SP_TYPE"][0]
    thequal=result_table["SP_QUAL"][0]
    #mag_V_vega=result_table["FLUX_V_2"][0]
    mag_U_vega=result_table["FLUX_U"][0]
    mag_B_vega=result_table["FLUX_B"][0]
    mag_V_vega=result_table["FLUX_V"][0]
    mag_R_vega=result_table["FLUX_R"][0]
    mag_I_vega=result_table["FLUX_I"][0]
        
    all_objnames.append(OBJNAME)
    all_tables.append(result_table)
    all_ra.append(skycoord.ra.degree)
    all_dec.append(skycoord.dec.degree)
    all_sp_type.append(thetype)
    all_sp_qual.append(thequal)
    all_mag_U.append(mag_U_vega)
    all_mag_B.append(mag_B_vega)
    all_mag_V.append(mag_V_vega)
    all_mag_R.append(mag_R_vega)
    all_mag_I.append(mag_I_vega)
    all_goodcalspecfile.append(file)
# Out:
# 10lac_stis_004.fits
# ============== 10LAC ===========================
#  MAIN_ID        RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#              "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# --------- ------------- ------------- ------- ... ------ ------ ------ ------
# *  10 Lac 22 39 15.6786 +39 03 00.971      11 ...   4.67   4.88   4.98   5.19
# 1732526_stisnic_004.fits
# ============== 1732526 ===========================
# >>>>> SKIP TARGET 1732526
# 1740346_stisnic_003.fits
# ============== 1740346 ===========================
# >>>>> SKIP TARGET 1740346
# 1743045_stisnic_004.fits
# ============== 1743045 ===========================
# >>>>> SKIP TARGET 1743045
# 1757132_stis_004.fits
# ============== 1757132 ===========================
# >>>>> SKIP TARGET 1757132
# 1802271_stisnic_004.fits
# ============== 1802271 ===========================
# >>>>> SKIP TARGET 1802271
# 1805292_stisnic_004.fits
# ============== 1805292 ===========================
# >>>>> SKIP TARGET 1805292
# 1808347_stis_004.fits
# ============== 1808347 ===========================
# >>>>> SKIP TARGET 1808347
# 1812095_stisnic_004.fits
# ============== 1812095 ===========================
# >>>>> SKIP TARGET 1812095
# 1812524_nic_004.fits
# ============== 1812524 ===========================
# >>>>> SKIP TARGET 1812524
# 2m003618_stisnic_006.fits
# ============== 2M0036+18 ===========================
# >>>>> SKIP TARGET 2M0036+18
# 2m055914_stisnic_006.fits
# ============== 2M0559-14 ===========================
# >>>>> SKIP TARGET 2M0559-14
# WDcovar_001.fits
# >>>>> SKIP file WDcovar_001.fits
# agk_81d266_stisnic_006.fits
# ============== AGK+81D266 ===========================
# >>>>> SKIP TARGET AGK+81D266
# alpha_lyr_stis_008.fits
# ============== ALPHA_LYR ===========================
#  MAIN_ID        RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#              "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# --------- ------------- ------------- ------- ... ------ ------ ------ ------
# * alf Lyr 18 36 56.3363 +38 47 01.280       9 ...   0.03   0.03   0.07    0.1
# bd02d3375_stis_003.fits
# ============== BD02D3375 ===========================
# >>>>> SKIP TARGET BD02D3375
# bd17d4708_stisnic_001.fits
# ============== BD17D4708 ===========================
# >>>>> SKIP TARGET BD17D4708
# bd21d0607_stis_003.fits
# ============== BD21D0607 ===========================
# >>>>> SKIP TARGET BD21D0607
# bd26d2606_stis_003.fits
# ============== BD26D2606 ===========================
# >>>>> SKIP TARGET BD26D2606
# bd29d2091_stis_003.fits
# ============== BD29D2091 ===========================
# >>>>> SKIP TARGET BD29D2091
# bd54d1216_stis_003.fits
# ============== BD54D1216 ===========================
# >>>>> SKIP TARGET BD54D1216
# bd60d1753_stis_004.fits
# ============== BD60D1753 ===========================
# >>>>> SKIP TARGET BD60D1753
# bd_75d325_stis_004.fits
# ============== BD75 ===========================
# >>>>> SKIP TARGET BD75
# c26202_stisnic_007.fits
# ============== C26202 ===========================
# >>>>> SKIP TARGET C26202
# etauma_stis_003.fits
# ============== ETAUMA ===========================
# >>>>> SKIP TARGET ETAUMA
# feige110_stisnic_006.fits
# ============== FEIGE110 ===========================
#  MAIN_ID        RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#              "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# --------- ------------- ------------- ------- ... ------ ------ ------ ------
# Feige 110 23 19 58.3995 -05 09 56.170      14 ...  11.45   11.5  11.97 12.145
# feige34_stis_004.fits
# ============== FEIGE34 ===========================
#  MAIN_ID        RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#              "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# --------- ------------- ------------- ------- ... ------ ------ ------ ------
# Feige  34 10 39 36.7377 +43 06 09.209      14 ...  10.91  11.14 11.319 11.464
# feige66_002.fits
# ============== FEIGE66 ===========================
#   MAIN_ID         RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#                "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# ----------- ------------- ------------- ------- ... ------ ------ ------ ------
# BD+25  2534 12 37 23.5157 +25 03 59.871      14 ...  10.26  10.59 10.642 10.809
# feige67_002.fits
# ============== FEIGE67 ===========================
#   MAIN_ID         RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#                "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# ----------- ------------- ------------- ------- ... ------ ------ ------ ------
# BD+18  2647 12 41 51.7901 +17 31 19.750      14 ...   11.7  11.63 11.969 12.159
# g191b2b_stisnic_006.fits
# ============== G191B2B ===========================
#   MAIN_ID         RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#                "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# ----------- ------------- ------------- ------- ... ------ ------ ------ ------
# BD+52   913 05 05 30.6182 +52 49 51.920      14 ...  11.44  11.69  11.93 12.108
# g93_48_004.fits
# ============== G93-48 ===========================
# MAIN_ID        RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#             "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# -------- ------------- ------------- ------- ... ------ ------ ------ ------
# EGGR 150 21 52 25.3788 +02 23 19.576      14 ... 12.732 12.743 12.839 12.938
# gd108_005.fits
# ============== GD108 ===========================
# MAIN_ID       RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#            "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# ------- ------------- ------------- ------- ... ------ ------ ------ ------
#  GD 108 10 00 47.2462 -07 33 30.777      14 ... 13.349 13.563 13.662 13.781
# gd153_stisnic_006.fits
# ============== GD153 ===========================
# MAIN_ID       RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#            "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# ------- ------------- ------------- ------- ... ------ ------ ------ ------
#  GD 153 12 57 02.3224 +22 01 52.634      14 ...  13.06 13.349 13.488 13.669
# gd50_004.fits
# ============== GD50 ===========================
# MAIN_ID       RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#            "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# ------- ------------- ------------- ------- ... ------ ------ ------ ------
#   GD 50 03 48 50.1861 -00 58 32.290      14 ... 13.787 14.063  14.21 14.388
# gd71_stisnic_006.fits
# ============== GD71 ===========================
# MAIN_ID       RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#            "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# ------- ------------- ------------- ------- ... ------ ------ ------ ------
#   GD 71 05 52 27.6197 +15 53 13.228      14 ... 12.783 13.032 13.169 13.337
# gj7541a_stis_003.fits
# ============== GJ7541A ===========================
# >>>>> SKIP TARGET GJ7541A
# grw_70d5824_stisnic_007.fits
# ============== GRW+70D5824 ===========================
# >>>>> SKIP TARGET GRW+70D5824
# hd009051_stis_003.fits
# ============== HD009051 ===========================
#  MAIN_ID        RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#              "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# --------- ------------- ------------- ------- ... ------ ------ ------ ------
# HD   9051 01 28 46.5026 -24 20 25.443      14 ...   9.73   8.92     --     --
# hd031128_stis_003.fits
# ============== HD031128 ===========================
#  MAIN_ID        RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#              "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# --------- ------------- ------------- ------- ... ------ ------ ------ ------
# HD  31128 04 52 09.9097 -27 03 50.940      14 ...   9.55   9.14     --     --
# hd074000_stis_003.fits
# ============== HD074000 ===========================
#  MAIN_ID        RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#              "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# --------- ------------- ------------- ------- ... ------ ------ ------ ------
# HD  74000 08 40 50.8038 -16 20 42.513      14 ...  10.09   9.66     --     --
# hd106252_stis_004.fits
# ============== HD106252 ===========================
#  MAIN_ID        RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#              "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# --------- ------------- ------------- ------- ... ------ ------ ------ ------
# HD 106252 12 13 29.5100 +10 02 29.888      14 ...    8.0     --    7.0     --
# hd111980_stis_003.fits
# ============== HD111980 ===========================
#  MAIN_ID        RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#              "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# --------- ------------- ------------- ------- ... ------ ------ ------ ------
# HD 111980 12 53 15.0528 -18 31 20.009      14 ...   8.91   8.38     --     --
# hd116405_stis_004.fits
# ============== HD116405 ===========================
#  MAIN_ID        RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#              "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# --------- ------------- ------------- ------- ... ------ ------ ------ ------
# HD 116405 13 22 45.1237 +44 42 53.911      14 ...   8.27   8.34     --     --
# hd14943_stis_004.fits
# ============== HD14943 ===========================
#  MAIN_ID        RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#              "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# --------- ------------- ------------- ------- ... ------ ------ ------ ------
# HD  14943 02 22 54.6752 -51 05 31.659      14 ...  6.101  5.898     --     --
# hd158485_stis_004.fits
# ============== HD158485 ===========================
#  MAIN_ID        RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#              "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# --------- ------------- ------------- ------- ... ------ ------ ------ ------
# HD 158485 17 26 04.8370 +58 39 06.831      14 ...  6.616  6.494     --     --
# hd159222_stis_004.fits
# ============== HD159222 ===========================
#  MAIN_ID        RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#              "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# --------- ------------- ------------- ------- ... ------ ------ ------ ------
# HD 159222 17 32 00.9922 +34 16 16.130      14 ...   7.21     --    6.1     --
# hd160617_stis_003.fits
# ============== HD160617 ===========================
#  MAIN_ID        RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#              "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# --------- ------------- ------------- ------- ... ------ ------ ------ ------
# HD 160617 17 42 49.3235 -40 19 15.505      14 ...   9.18   8.73  8.394  8.065
# hd163466_stis_004.fits
# ============== HD163466 ===========================
#  MAIN_ID        RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#              "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# --------- ------------- ------------- ------- ... ------ ------ ------ ------
# HD 163466 17 52 25.3756 +60 23 46.940      14 ...   7.04   6.85     --     --
# hd165459_stisnic_004.fits
# ============== HD165459 ===========================
#  MAIN_ID        RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#              "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# --------- ------------- ------------- ------- ... ------ ------ ------ ------
# HD 165459 18 02 30.7410 +58 37 38.157      14 ...   6.98   6.86     --    6.7
# hd180609_stis_004.fits
# ============== HD180609 ===========================
#  MAIN_ID        RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#              "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# --------- ------------- ------------- ------- ... ------ ------ ------ ------
# HD 180609 19 12 47.1995 +64 10 37.174      14 ...   9.57   9.42     --     --
# hd185975_stis_003.fits
# ============== HD185975 ===========================
#  MAIN_ID        RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#              "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# --------- ------------- ------------- ------- ... ------ ------ ------ ------
# HD 185975 20 28 18.7402 -87 28 19.938      14 ...   8.78    8.1     --     --
# hd200654_stis_003.fits
# ============== HD200654 ===========================
#  MAIN_ID        RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#              "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# --------- ------------- ------------- ------- ... ------ ------ ------ ------
# HD 200654 21 06 34.7513 -49 57 50.282      14 ...   9.74   9.11     --     --
# hd205905_stis_004.fits
# ============== HD205905 ===========================
#  MAIN_ID        RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#              "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# --------- ------------- ------------- ------- ... ------ ------ ------ ------
# HD 205905 21 39 10.1510 -27 18 23.666      14 ...   7.36   6.74     --     --
# hd209458_stisnic_007.fits
# ============== HD209458 ===========================
#   MAIN_ID         RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#                "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# ----------- ------------- ------------- ------- ... ------ ------ ------ ------
# V* V376 Peg 22 03 10.7729 +18 53 03.548      14 ...   8.21   7.63     --     --
# hd37725_stis_004.fits
# ============== HD37725 ===========================
#  MAIN_ID        RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#              "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# --------- ------------- ------------- ------- ... ------ ------ ------ ------
# HD  37725 05 41 54.3696 +29 17 50.956      14 ...   8.12   8.31     --     --
# hd37962_stis_004.fits
# ============== HD37962 ===========================
#  MAIN_ID        RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#              "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# --------- ------------- ------------- ------- ... ------ ------ ------ ------
# HD  37962 05 40 51.9659 -31 21 03.985      14 ...    8.5   7.85     --     --
# hd38949_stis_004.fits
# ============== HD38949 ===========================
#  MAIN_ID        RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#              "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# --------- ------------- ------------- ------- ... ------ ------ ------ ------
# HD  38949 05 48 20.0588 -24 27 49.853      14 ...   8.37    7.8     --     --
# hd60753_stis_003.fits
# ============== HD60753 ===========================
#  MAIN_ID        RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#              "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# --------- ------------- ------------- ------- ... ------ ------ ------ ------
# HD  60753 07 33 27.3190 -50 35 03.311      14 ...  6.587   6.68     --     --
# hd93521_stis_004.fits
# ============== HD93521 ===========================
#  MAIN_ID        RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#              "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# --------- ------------- ------------- ------- ... ------ ------ ------ ------
# HD  93521 10 48 23.5116 +37 34 13.089      14 ...   6.79   7.03     --     --
# hs2027_stis_004.fits
# ============== HS2027 ===========================
# >>>>> SKIP TARGET HS2027
# hz21_stis_004.fits
# ============== HZ21 ===========================
# MAIN_ID       RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#            "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# ------- ------------- ------------- ------- ... ------ ------ ------ ------
#   HZ 21 12 13 56.2639 +32 56 31.359      14 ... 14.361 14.688 14.837 15.038
# hz2_005.fits
# ============== HZ2 ===========================
# MAIN_ID       RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#            "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# ------- ------------- ------------- ------- ... ------ ------ ------ ------
#   HZ  2 04 12 43.5549 +11 51 48.973      14 ... 13.787 13.877 13.984 14.094
# hz43_stis_004.fits
# ============== HZ43 ===========================
# MAIN_ID       RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#            "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# ------- ------------- ------------- ------- ... ------ ------ ------ ------
#   HZ 43 13 16 21.8532 +29 05 55.379       9 ...  12.52  12.66     --     --
# hz43b_stis_004.fits
# ============== HZ43B ===========================
# >>>>> SKIP TARGET HZ43B
# hz44_stis_004.fits
# ============== HZ44 ===========================
# MAIN_ID       RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#            "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# ------- ------------- ------------- ------- ... ------ ------ ------ ------
#   HZ 44 13 23 35.2632 +36 07 59.545      14 ...  11.42  11.65   12.0 11.995
# hz4_stis_005.fits
# ============== HZ4 ===========================
# MAIN_ID       RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#            "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# ------- ------------- ------------- ------- ... ------ ------ ------ ------
#   HZ  4 03 55 21.9881 +09 47 18.134      14 ... 14.592 14.506  14.58 14.642
# kf01t5_nic_003.fits
# ============== KF01T5 ===========================
# >>>>> SKIP TARGET KF01T5
# kf06t1_nic_003.fits
# ============== KF06T1 ===========================
# >>>>> SKIP TARGET KF06T1
# kf06t2_stisnic_004.fits
# ============== KF06T2 ===========================
# >>>>> SKIP TARGET KF06T2
# kf08t3_stisnic_001.fits
# ============== KF08T3 ===========================
# >>>>> SKIP TARGET KF08T3
# ksi2ceti_stis_004.fits
# ============== KSI2CETI ===========================
# >>>>> SKIP TARGET KSI2CETI
# lamlep_stis_004.fits
# ============== LAMLEP ===========================
# >>>>> SKIP TARGET LAMLEP
# lb227_004.fits
# ============== LB227 ===========================
# MAIN_ID        RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#             "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# -------- ------------- ------------- ------- ... ------ ------ ------ ------
# EGGR  29 04 09 28.9036 +17 07 54.391      14 ... 15.378 15.323 15.408 15.515
# lds749b_stisnic_006.fits
# ============== LDS749B ===========================
# MAIN_ID       RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#            "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# ------- ------------- ------------- ------- ... ------ ------ ------ ------
# LAWD 87 21 32 16.2327 +00 15 14.398      14 ... 14.634 14.674 14.675 14.676
# ltt9491_002.fits
# ============== LTT9491 ===========================
# MAIN_ID        RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#             "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# -------- ------------- ------------- ------- ... ------ ------ ------ ------
# EGGR 264 23 19 35.3881 -17 05 28.468      14 ... 14.132 14.111  14.07 14.049
# mucol_stis_004.fits
# ============== MUCOL ===========================
# >>>>> SKIP TARGET MUCOL
# ngc7293_005.fits
# ============== NGC7293 ===========================
#  MAIN_ID        RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#              "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# --------- ------------- ------------- ------- ... ------ ------ ------ ------
# NGC  7293 22 29 38.5453 -20 50 13.746      14 ... 13.158 13.524 13.689 13.898
# p041c_stisnic_007.fits
# ============== P041C ===========================
# >>>>> SKIP TARGET P041C
# p177d_stisnic_007.fits
# ============== P177D ===========================
# >>>>> SKIP TARGET P177D
# p330e_stisnic_008.fits
# ============== P330E ===========================
# >>>>> SKIP TARGET P330E
# sf1615001a_stisnic_001.fits
# ============== SF1615001A ===========================
# >>>>> SKIP TARGET SF1615001A
# sf1615_001a_stisnic_007.fits
# ============== SF1615+001A ===========================
# >>>>> SKIP TARGET SF1615+001A
# sirius_stis_002.fits
# ============== SIRIUS ===========================
#  MAIN_ID        RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#              "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# --------- ------------- ------------- ------- ... ------ ------ ------ ------
# * alf CMa 06 45 08.9172 -16 42 58.017       9 ...  -1.46  -1.46  -1.46  -1.43
# snap1_stisnic_006.fits
# ============== SNAP-1 ===========================
# >>>>> SKIP TARGET SNAP-1
# snap2_stisnic_007.fits
# ============== SNAP-2 ===========================
# >>>>> SKIP TARGET SNAP-2
# sun_reference_stis_002.fits
# ============== SUN_REFERENCE ===========================
# >>>>> SKIP TARGET SUN_REFERENCE
# vb8_stisnic_006.fits
# ============== VB8 ===========================
# >>>>> SKIP TARGET VB8
# wd0308_565_stis_004.fits
# ============== WD0308-565 ===========================
# MAIN_ID       RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#            "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# ------- ------------- ------------- ------- ... ------ ------ ------ ------
#  WG   7 03 09 47.9177 -56 23 49.413      14 ...  13.99  14.14  14.42     --
# wd0320_539_stis_004.fits
# ============== WD0320-539 ===========================
# >>>>> SKIP TARGET WD0320-539
# wd0947_857_stis_004.fits
# ============== WD0947_857 ===========================
# >>>>> SKIP TARGET WD0947_857
# wd1026_453_stis_004.fits
# ============== WD1026_453 ===========================
# >>>>> SKIP TARGET WD1026_453
# wd1057_719_stisnic_006.fits
# ============== WD1057+719 ===========================
#   MAIN_ID         RA           DEC      RA_PREC ... FLUX_B FLUX_V FLUX_R FLUX_I
#                "h:m:s"       "d:m:s"            ...  mag    mag    mag    mag
# ----------- ------------- ------------- ------- ... ------ ------ ------ ------
# PG 1057+719 11 00 34.2433 +71 38 02.919      14 ...  14.95  14.68  15.23     --

# %% [markdown]
# # Create an astropy table to save good calspec

# %%
t = Table()

# %%
t["OBJNAME"]=all_objnames
t["RA"]=all_ra
t["DEC"]=all_dec
t["SP_TYPE"]=all_sp_type
t["SP_QUAL"]=all_sp_qual
t["magU"]=all_mag_U
t["magB"]=all_mag_B
t["magV"]=all_mag_V
t["magR"]=all_mag_R
t["magI"]=all_mag_I
t["FILES"]=all_goodcalspecfile
# Out:
# /Users/dagoret/anaconda3/lib/python3.7/site-packages/numpy/ma/core.py:2786: UserWarning: Warning: converting a masked element to nan.
#   order=order, subok=True, ndmin=ndmin)

# %%
t["RA"].info.format ='5.3f'
t["DEC"].info.format ='5.3f'
t["magU"].info.format ='5.3f'
t["magB"].info.format ='5.3f'
t["magV"].info.format ='5.3f'
t["magR"].info.format ='5.3f'
t["magI"].info.format ='5.3f'

# %%
t.show_in_notebook()
# Out:
# <i>Table length=46</i>
# <table id="table4871333328-693669" class="table-striped table-bordered table-condensed">
# <thead><tr><th>idx</th><th