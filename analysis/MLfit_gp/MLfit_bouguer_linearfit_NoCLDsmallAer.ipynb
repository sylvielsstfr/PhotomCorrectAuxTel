# %% [markdown]
# # Fit Instrument transmission using Linear Fit in numpy

# %% [markdown]
# The purpose is to fit Bouguer lines to find Instrument transmission : Demonstration for DESC plenary meeting
#
#
# - author Sylvie Dagoret-Campagne
# - affiliation : IJCLab/IN2P3/CNRS
# - creation date : February 19th 2022
# - update : September 23th 2020  : cut tail for order 2
# - update : october 6th 2020 : Set surface to 1cm2 in pysynphot

# %% [markdown]
# # imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
import os,sys,re

from astropy.io import fits
import matplotlib.colors as colors
import matplotlib.cm as cmx
import matplotlib.dates as mdates
from matplotlib import gridspec
from mpl_toolkits.axes_grid.inset_locator import (inset_axes, InsetPosition,
                                                  mark_inset)
# %matplotlib inline
# Out:
# <ipython-input-1-526d3f2e8ec9>:13: MatplotlibDeprecationWarning:
# The mpl_toolkits.axes_grid module was deprecated in Matplotlib 2.1 and will be removed two minor releases later. Use mpl_toolkits.axes_grid1 and mpl_toolkits.axisartist, which provide the same functionality instead.
#   from mpl_toolkits.axes_grid.inset_locator import (inset_axes, InsetPosition,

# %%
# to enlarge the sizes
params = {#'legend.fontsize': 'xx-large',
          'figure.figsize': (10, 8),
         'axes.labelsize': 'xx-large',
         'axes.titlesize':'xx-large',
         'xtick.labelsize':'xx-large',
         'ytick.labelsize':'xx-large'}
plt.rcParams.update(params)

# %%
from astropy.table import Table

# %%
from scipy import interpolate

# %%
from scipy.stats import rayleigh,beta,gamma,uniform

# %%
# analytic for removing rayleigh
sys.path.append("../../tools/atmanalyticsim") # go to parent dir

# %%
import libatmscattering as atm

# %%
import seaborn as sns

# %%
# pysynphot
import pysynphot as S
S.refs.setref(area=1)
S.refs.getref()
# Out:
# {'graphtable': '/Users/dagoret/MacOSX/External/PySynPhotData/grp/hst/cdbs/mtab/14l1632sm_tmg.fits',
#  'comptable': '/Users/dagoret/MacOSX/External/PySynPhotData/grp/hst/cdbs/mtab/16n1832tm_tmc.fits',
#  'thermtable': '/Users/dagoret/MacOSX/External/PySynPhotData/grp/hst/cdbs/mtab/tae17277m_tmt.fits',
#  'area': 1,
#  'waveset': 'Min: 500, Max: 26000, Num: 10000, Delta: None, Log: True'}

# %%
pysynphot_root_path=os.environ['PYSYN_CDBS']
path_sed_calspec=os.path.join(pysynphot_root_path,'calspec')

# %%
import scipy.special as sp

# %%
PATH_LSSTFiltersKG='../../data/lsst/LSSTFiltersKG'
sys.path.append(PATH_LSSTFiltersKG)
PATH_LSSTFiltersKGDATA='../../data/lsst/LSSTFiltersKG/fdata'
sys.path.append(PATH_LSSTFiltersKGDATA)

# %%
import libLSSTFiltersKG as lsst
# Out:
# liblsstfilter_path= ../../data/lsst/LSSTFiltersKG

# %%
import time
from datetime import datetime,date
import dateutil.parser
import pytz

import argparse

import logging
import coloredlogs
import configparser

# %% [markdown]
# # Pre defined Functions

# %%
def find_nearest(a, a0):
    "Element in nd array `a` closest to the scalar value `a0`"
    idx = np.abs(a - a0).argmin()
    return a.flat[idx],int(idx)

# %% [markdown]
# ## Functions to select the CALSPEC

# %%
def GetListOfCalspec(file_sedsummary="sed/table_summary_allcalspec_torenorm.fits"):
    """
    GetListOfCalspec()
    
    the file include SED fro which color term has been caculated 
    in /examples_sed/calspec/ViewCalspecColors.ipynb
    
    - input:
      file_sedsummary : filename of SED summary
      
    - output:
      t : astropy table of summary 
    """

    t=Table.read(file_sedsummary)
    return t

# %%
def SelectFewSED(t):
    """
    SelectFewSED(t)
    
    input : 
     - t astropy table of SED
     
    output :
    - t_selected : table of presselected SED
     
    """
    
    all_colors=t["VmI"]
    
    
    # list of target colors
    target_VmI=np.array([-0.75,-0.5,-0.25,0,0.25,0.5,0.75,1])
    NBVmItarget=len(target_VmI)
    
    filesselected_index=np.zeros(NBVmItarget)
    filesselected_VmI=np.zeros(NBVmItarget)
    
    idx=0
    for vmi in target_VmI:
        thevmi,theidx=find_nearest(all_colors,vmi)
        #print(thevmi,theidx)
        filesselected_index[idx]=int(theidx)
        filesselected_VmI[idx]=thevmi
        idx+=1  
        
    t_selected=Table(t[0])
    for idx in filesselected_index[1:]:
        t_selected.add_row(t[int(idx)])
        
    return t_selected

# %%
def plot_sed(t,ax):
    """
    
    plot_sed(t, ax) : Plot SED from the astropy table t

    input:
        - t : tables of SED
        - ax : matplotlib axis

    """
    
    NBFILES=len(t)
    
    # wavelength bin colors
    jet = plt.get_cmap('jet')
    cNorm = colors.Normalize(vmin=0, vmax=NBFILES)
    scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)
    all_colors = scalarMap.to_rgba(np.arange(NBFILES), alpha=1)
    
    idx=0
    
    flatsp = S.FlatSpectrum(10, fluxunits='photlam')

    for filename in t["FILES"]:
    
        # read the calspec file
        fullfilename=os.path.join(path_sed_calspec,filename)
        
        if filename=="flat":
            spec=flatsp
            spec_norm=spec
        else:
            spec=S.FileSpectrum(fullfilename)
        
        spec_norm = spec.renorm(10, 'vegamag', S.ObsBandpass('johnson,v'))
    
        spec_norm.convert('photlam')
        #spec_norm.convert('nm')    
        
        #WLMINSEL=340.
        #WLMAXSEL=1100.


        magV=t["magV"][idx]
        label=t["OBJNAME"][idx]+" ( "+t["SP_TYPE"][idx]+" ) "+" magV = {:.2g}".format(magV) +" v-i ={:.2f}".format(t["VmI"][idx])
        
        
        
        #X= spec_norm.wave[wavelengths_indexes]    
        #Y= spec_norm.flux[wavelengths_indexes]  
        
        X= spec_norm.wave   
        Y= spec_norm.flux 
        
        wavelengths_indexes=np.where(np.logical_and(spec_norm.wave>WLMINSEL*10, spec_norm.wave<WLMAXSEL*10))[0]
        
        
        #if filename!="flat":
        cm=ax.plot(X[wavelengths_indexes], Y[wavelengths_indexes],color=all_colors[idx],label=label)
        
        idx+=1
    
    #ax.set_xlim(3500.,11000.)
    #ax.set_ylim(0.,3.)
    ax.legend()
    ax.grid()


    xlabel=' $\\lambda$ (Angstrom)'
    ylabel=' Flux (photlam) normalised to Mag-10'
    ax.set_xlabel(xlabel,fontsize=15)
    ax.set_ylabel(ylabel,fontsize=15)
    ax.set_title("Preselected CALSPEC relative SED")
    
    return cm

# %% [markdown]
# ## Functions to build spectrum

# %%
def GetSpectra(sed,wl_atm,atm_transmission, order2=False,cut=False):
    """
    
    Compute the observed flux : SED x ATM transm x HOLO transm x TELESCOPE transm x CCD Transm
    
    * input : 
     - sed : Pysynphot SED
     -  wl  : wavelength of the atmospheric transmission (nm)
     - transmission : atmospheric transmission array
     - order2 : flag to compute the atmospheric transmission
     
    * output :
     - array of spectra (corresponding to wl in nm)
    
    """
    
    wl0=sed.wave  # in angstrom
    spectra=np.zeros_like(atm_transmission)
    spectra2=np.zeros_like(atm_transmission)  # order 2
    
    wl_atm_ang=10*wl_atm
    
   
    
    # quantum efficiency
    wl_ccd,throughput,ccdqe,trans_opt_elec=lsst.GetThroughputAndCCDQE("../../data/lsst")
    bp_qe= S.ArrayBandpass(wl_ccd*10.,ccdqe, name='QE')
    
    
    
    # passband for atmosphere
    Natm=atm_transmission.shape[0]
    all_bp_atm=[]
    for i_atm in np.arange(Natm):
        label_atm="atm{:d}".format(i_atm)
        bp_atm= S.ArrayBandpass(wl_atm_ang,atm_transmission[i_atm,:], name=label_atm)
        all_bp_atm.append(bp_atm)
        
    # Hologram transmission (analytic)
    X0=10000 # in angstrom
    X=wl0
    X2=np.sort(np.unique(np.concatenate((wl0/2,wl0)))) 
    Eff_holo=sp.jv(1, X0/X)**2
    Eff_holo2=sp.jv(2, X0/X2)**2
    
    bp_holo_order1= S.ArrayBandpass(X,Eff_holo, name='Holo')
    bp_holo_order2= S.ArrayBandpass(X2,Eff_holo2, name='Holo2')
    
    all_obs1=[]
    all_obs2=[]
    
    # compute spectra for order 1 and order 2
    for i_atm in np.arange(Natm):
        
        # MULTIPLY QE TRANS x ATM TRANSMISSION x HOLOGRAM TRANSMISSION
        bp_all_order1=bp_qe*all_bp_atm[i_atm]* bp_holo_order1
        bp_all_order2=bp_qe*all_bp_atm[i_atm]* bp_holo_order2

        obs1 = S.Observation(sed, bp_all_order1,force='taper') # order 1
        obs2 = S.Observation(sed, bp_all_order2,force='taper') # order 2
    
        all_obs1.append(obs1)
        all_obs2.append(obs2)
        
   
    for i_atm in np.arange(Natm):
        obs1=all_obs1[i_atm]
        func_order1 = interpolate.interp1d(obs1.binwave,obs1.binflux,bounds_error=False,fill_value=(0,0))
    
        spectra[i_atm,:]=func_order1(wl_atm_ang) 
    
        obs2=all_obs2[i_atm]
        func_order2 = interpolate.interp1d(2*obs2.binwave,obs2.binflux/2,bounds_error=False,fill_value=(0,0))
        spectra2[i_atm,:]=func_order2(wl_atm_ang) 
      
    if cut:
         wlcut_indexes = np.where(wl_atm_ang<7600)[0]
         spectra2[:,wlcut_indexes]=0
        
    # add order 1 + order 2    
    if order2:
        spectra=spectra+spectra2
        
    spectra=spectra*10 # to get per unit of nm
    spectra2=spectra2*10
    
    return spectra,spectra2

# %%
def GetSpectraNoAtm(sed,wl_atm,atm_transmission, order2=False,cut=False):
    """
    
     Compute the flux : SED x  HOLO transm 
     
     - no atm transmission and no telescope transmission
    
    * input : 
     - sed : Pysynphot SED
     -  wl  : wavelength of the atmospheric transmission (nm)
     - transmission : atmospheric transmission array
     - order2 : flag to compute the atmospheric transmission
     
    * output :
     - array of spectra (corresponding to wl in nm)
    
    """
    
    wl0=sed.wave  # in angstrom
    spectra=np.zeros_like(atm_transmission)
    spectra2=np.zeros_like(atm_transmission)  # order 2
    
    wl_atm_ang=10*wl_atm
    
    
    
    # quantum efficiency
    wl_ccd,throughput,ccdqe,trans_opt_elec=lsst.GetThroughputAndCCDQE("../../data/lsst")
    bp_qe= S.ArrayBandpass(wl_ccd*10.,ccdqe, name='QE')
    
    
    
    # passband for atmosphere
    Natm=atm_transmission.shape[0]
    all_bp_atm=[]
    for i_atm in np.arange(Natm):
        label_atm="atm{:d}".format(i_atm)
        bp_atm= S.ArrayBandpass(wl_atm_ang,atm_transmission[i_atm,:], name=label_atm)
        all_bp_atm.append(bp_atm)
        
    # Hologram transmission (analytic)
    X0=10000 # in antstrom
    X=wl0
    X2=np.sort(np.unique(np.concatenate((wl0/2,wl0)))) 
    Eff_holo=sp.jv(1, X0/X)**2
    Eff_holo2=sp.jv(2, X0/X2)**2
    
    bp_holo_order1= S.ArrayBandpass(X,Eff_holo, name='Holo')
    bp_holo_order2= S.ArrayBandpass(X2,Eff_holo2, name='Holo2')
    
    all_obs1=[]
    all_obs2=[]
    
    # compute spectra for order 1 and order 2
    # remoove atmosphere and qe
    # keep  hologram
    for i_atm in np.arange(Natm):
        #bp_all_order1=bp_qe*all_bp_atm[i_atm]* bp_holo_order1
        #bp_all_order2=bp_qe*all_bp_atm[i_atm]* bp_holo_order2
        
        bp_all_order1 = bp_holo_order1
        bp_all_order2 = bp_holo_order2

        # PUT ONLY HOLOGRAM TRANSMISSION
        obs1 = S.Observation(sed, bp_all_order1,force='taper') # order 1
        obs2 = S.Observation(sed, bp_all_order2,force='taper') # order 2
    
        all_obs1.append(obs1)
        all_obs2.append(obs2)
        
   
    for i_atm in np.arange(Natm):
        obs1=all_obs1[i_atm]
        func_order1 = interpolate.interp1d(obs1.binwave,obs1.binflux,bounds_error=False,fill_value=(0,0))
    
        spectra[i_atm,:]=func_order1(wl_atm_ang) 
    
        obs2=all_obs2[i_atm]
        func_order2 = interpolate.interp1d(2*obs2.binwave,obs2.binflux/2,bounds_error=False,fill_value=(0,0))
        spectra2[i_atm,:]=func_order2(wl_atm_ang) 
        
    if cut:
        wlcut_indexes = np.where(wl_atm_ang<7600)[0]
        spectra2[:,wlcut_indexes]=0
        
    # add order 1 + order 2    
    if order2:
        spectra=spectra+spectra2
        
    spectra=spectra*10 # to get per unit of nm
    spectra2=spectra2*10
    
    return spectra,spectra2

# %% [markdown]
# ## Functions for Plotting

# %%
def plot_param(iparam,ax,all_Yin,all_Yout,mode,nsig=10):
    """
    plot estimated parameters
    
    iparam = 0,1,2,3 : VAOD,PWV,O3,CLD
    ax     = axis
    
    all_Yin : inverse transform of the input in the simulation
    all_Yout : inverse transform predicted parameters
    
    mode : 
    - 0 : Yout vs Yin
    - 1 : Yout - Yin vs Yin
    - 2 : (Yout - Yin)/Yin vs Yin
    
    """
    N=4 # color mode corres ponding to parameter
    jet = plt.get_cmap('jet')
    cNorm = colors.Normalize(vmin=0, vmax=N)
    scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)
    all_colors = scalarMap.to_rgba(np.arange(N), alpha=1)

    xlabel=["VAOD in ","PWV in (mm)","Ozone in (dBU)","Cloud OD in "]
    ylabel=["value out","value rec - value in","$\delta V/V$"]
    ttitle=["Estimation of VAOD",
       "Estimation of PWV",
       "Estimation of Ozone",
       "Estimation of Cloud OD"]
     
    DY=all_Yout[:,iparam]-all_Yin[:,iparam]
    Y0=all_Yin[:,iparam]
    Y1=all_Yout[:,iparam]
    RY=DY/Y0
    
    if mode   ==0:  
        cm=ax.plot(Y0,Y1,"o",color=all_colors[iparam])
    elif mode ==1:
        
        mu = DY.mean()
        median = np.median(DY)
        sigma = DY.std()
        textstr = '\n'.join((
        r'$\mu$={:3.2g}'.format(mu),
        r'$median$={:3.2g}'.format(median),
        r'$\sigma$={:3.2g}'.format(sigma)))
        
       
        cm=ax.plot(Y0,DY,"o",color=all_colors[iparam])
        
        # these are matplotlib.patch.Patch properties
        props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)

        # place a text box in upper left in axes coords
        ax.text(0.05, 0.95, textstr, transform=ax.transAxes, fontsize=14,verticalalignment='top', bbox=props)
        
        ax.set_ylim(mu-nsig*sigma,mu+nsig*sigma)
        
    else:
        
        mu = RY.mean()
        median = np.median(RY)
      
        sigma = RY.std()
        
        
        textstr = '\n'.join((
        '$\mu$={:.3g}'.format(mu),
        '$median$={:.3g}'.format(median),
        '$\sigma$={:.3g}'.format(sigma)))
       
        
        
        cm=ax.plot(Y0,RY,"o",color=all_colors[iparam])
        
        # these are matplotlib.patch.Patch properties
        props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)

        # place a text box in upper left in axes coords
        ax.text(0.05, 0.95, textstr, transform=ax.transAxes, fontsize=14,verticalalignment='top', bbox=props)
            
        ax.set_ylim(mu-nsig*sigma,mu+nsig*sigma)    
            
    ax.grid()
    ax.set_title(ttitle[iparam])
    ax.set_xlabel(xlabel[iparam])
    ax.set_ylabel(ylabel[mode])

    
    ax.ticklabel_format(axis='y',style='sci', 
                          scilimits=None, 
                          useOffset=None, 
                          useLocale=None, 
                          useMathText=True)
    
    return cm

# %%
def plot_param_histo(iparam,ax,all_Yin,all_Yout,nsig=10):
    """
    plot histo of parameters
    
    iparam = 0,1,2,3 : VAOD,PWV,O3,CLD
    ax     = axis
    
    all_Yin : inverse transform of the input in the simulation
    all_Yout : inverse transform predicted parameters
    
    mode : 
    - 0 : Yout vs Yin
    - 1 : Yout - Yin vs Yin
    - 2 : (Yout - Yin)/Yin vs Yin
    
    """
    N=4 # color mode corres ponding to parameter
    jet = plt.get_cmap('jet')
    cNorm = colors.Normalize(vmin=0, vmax=N)
    scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)
    all_colors = scalarMap.to_rgba(np.arange(N), alpha=1)

     
    DY=all_Yout[:,iparam]-all_Yin[:,iparam]
    Y0=all_Yin[:,iparam]
    Y1=all_Yout[:,iparam]
    RY=DY/Y0
    

    xlabel=["$\Delta$ VAOD","$\Delta$ PWV (mm)","$\Delta$ Ozone (dBU)","$\Delta$ OD"]
   
    ttitle=["Estimation of VAOD",
       "Estimation of PWV",
       "Estimation of Ozone",
       "Estimation of Cloud OD"]

    
    mu = DY.mean()
    median = np.median(DY)
    sigma = DY.std()
    textstr = '\n'.join((
    '$\mu$={:.3g}'.format(mu),
    '$median$={:.3g}'.format(median),
    '$\sigma$={:.3g}'.format(sigma)))
   
    
    cm=ax.hist(DY,bins=50,color=all_colors[iparam])
    ax.grid()
    ax.set_title(ttitle[iparam])
    ax.set_xlabel(xlabel[iparam])
    ax.set_xlim(mu-nsig*sigma,mu+nsig*sigma)
    
    # these are matplotlib.patch.Patch properties
    props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)

    # place a text box in upper left in axes coords
    ax.text(0.05, 0.95, textstr, transform=ax.transAxes, fontsize=14,verticalalignment='top', bbox=props)
 
    ax.ticklabel_format(axis='x', 
                          style='sci',
                          scilimits=(-3,-3), 
                          useOffset=None, 
                          useLocale=None, 
                          useMathText=True)
    
    return cm

# %%
def plotcorrelation(ax,all_Y):
    """
    """
    
    df=pd.DataFrame(data=all_Y,columns=['VAOD', 'PWV', 'OZONE',"CLD-OD"])
    Var_Corr = df.corr()
    mask_ut=np.triu(np.ones(Var_Corr.shape)).astype(np.bool)
    mask_lt=np.logical_not(np.tril(np.ones(Var_Corr.shape)).astype(np.bool))
    
    sns.heatmap(Var_Corr,mask=mask_lt,vmin=0, vmax=1 ,xticklabels=Var_Corr.columns, yticklabels=Var_Corr.columns, annot=True,ax=ax,cmap="jet")

# %%
#-----------------------------------------------------------------------------------------------------------------------
def plot_ml_result(Yin,Yout,mode,title):
    """
    plot_ml_result(Yin,Yout,mode,title)

    :param Yin:
    :param Yout:
    :param mode:
    :param title:
    :return:
    """

    fig = plt.figure(figsize=(8.5, 7.5))
    ax = fig.add_subplot(221)
    plot_param(0, ax, Yin, Yout, mode)

    ax = fig.add_subplot(222)
    plot_param(1, ax,Yin, Yout, mode)

    ax = fig.add_subplot(223)
    plot_param(2, ax, Yin, Yout, mode)

    ax = fig.add_subplot(224)
    plot_param(3, ax, Yin, Yout, mode)

    plt.tight_layout()
    plt.suptitle(title, Y=1.02, fontsize=18)
    plt.show()
#--------------------------------------------

# %%
def histo_ml_result(Yin, Yout, title):
    """

    :param Yin:
    :param Yout:
    :param mode:
    :param title:
    :return:
    """

    fig = plt.figure(figsize=(8.5, 7.5))
    ax = fig.add_subplot(221)
    plot_param_histo(0, ax, Yin, Yout)

    ax = fig.add_subplot(222)
    plot_param_histo(1, ax, Yin, Yout)

    ax = fig.add_subplot(223)
    plot_param_histo(2, ax, Yin, Yout)

    ax = fig.add_subplot(224)
    plot_param_histo(3, ax, Yin, Yout)

    plt.tight_layout()
    plt.suptitle(title, Y=1.02, fontsize=18)
    plt.show()
#---------------------------------------------

# %%
def plot_regularisation_coeff(alphas,alpha0,allcoefs,title):
    """

    plot_regularisation_coeff(alpha,all_coeff,title) : plot coefficient vrt regularisation parameter

    :param alphas: regularisation parameters
    : param alpha0 : vertical line
    :param allcoefs: coefficient
    :param title: title
    :return:
    """

    N = allcoefs.shape[2] # number of coefficients
    jet = plt.get_cmap('jet')
    cNorm = colors.Normalize(vmin=0, vmax=N)
    scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)
    all_colors = scalarMap.to_rgba(np.arange(N), alpha=1)

    fig = plt.figure(figsize=(12, 8))

    ax1 = fig.add_subplot(221)
    for idx in np.arange(allcoefs.shape[2]):
        ax1.plot(alphas, allcoefs[:, 0, idx], color=all_colors[idx])
    ax1.set_xscale('log')
    ax1.axvline(x=alpha0, color='red')
    ax1.set_ylabel('weights - vaod')
    ax1.set_xlim(ax1.get_xlim()[::-1])  # reverse axis
    ax1.grid(True)
    ax1.set_title(title)

    ax2 = fig.add_subplot(222, sharex=ax1)
    for idx in np.arange(allcoefs.shape[2]):
        ax2.plot(alphas, allcoefs[:, 1, idx], color=all_colors[idx])
    ax2.axvline(x=alpha0, color='red')
    ax2.set_xscale('log')
    ax2.set_ylabel('weights - H2O')
    ax2.set_xlim(ax2.get_xlim()[::-1])  # reverse axis
    ax2.grid(True)

    ax3 = fig.add_subplot(223, sharex=ax1)
    for idx in np.arange(allcoefs.shape[2]):
        ax3.plot(alphas, allcoefs[:, 2, idx], color=all_colors[idx])
    ax3.axvline(x=alpha0, color='red')
    ax3.set_ylabel('weights - O3')
    ax3.set_xscale('log')
    ax3.set_xlim(ax3.get_xlim()[::-1])  # reverse axis
    ax3.grid(True)

    ax4 = fig.add_subplot(224, sharex=ax1)
    for idx in np.arange(allcoefs.shape[2]):
        ax4.plot(alphas, allcoefs[:, 3, idx], color=all_colors[idx])
    ax4.axvline(x=alpha0, color='red')
    ax4.set_ylabel('weights - CLD')
    ax4.set_xscale('log')
    # ax4.set_xlim(ax4.get_xlim()[::-1])  # reverse axis
    ax4.set_xlim(ax4.get_xlim())  # reverse axis
    ax4.grid(True)

    plt.xlabel('alpha')
    plt.axis('tight')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # GetAtmTransparency

# %%
def GetAtmTransparency(inputdir,filelist):
    """
    GetAtmTransparency(inputdir, filelist): retrieve atmospheric transparency from simulation

    input arguments:
     - inputdir : input directory
     - filelist : list of file to read
    """
    
    filename=filelist[0]
    full_inputfilename=os.path.join(inputdir,filename)
    hduin = fits.open(full_inputfilename)
    
    headerin=hduin[0].header
    datain=hduin[0].data
    
    hdr=headerin
    NSIMH=hdr['NBATMSIM']
    idx_num = hdr['ID_NUM']
    idx_am = hdr['ID_AM']
    idx_vaod=hdr['ID_VAOD']
    idx_pwv= hdr['ID_PWV']
    idx_o3=hdr['ID_O3']
    idx_cld=hdr['ID_CLD']
    idx_res= hdr['ID_RES']
    
    wl=datain[0,idx_res:]
    
    hduin.close() 
    
    all_data=[]
    # loop on files to extract data
    for file in filelist:
        full_inputfilename=os.path.join(inputdir,file)
        hdu = fits.open(full_inputfilename)
       
        datain=hdu[0].data
        all_data.append(datain[1:,:])
        hdu.close
        
    dataout=np.concatenate(all_data,axis=0)
    
    return wl,dataout,idx_num,idx_am,idx_vaod,idx_pwv,idx_o3,idx_cld,idx_res,headerin

# %% [markdown]
# # Initialisation

# %%
# date
today = date.today()
string_date = today.strftime("%Y-%m-%d")


# time
now = datetime.now()
current_time = now.strftime("%H:%M:%S")

tim = time.localtime()
current_time = time.strftime("%H:%M:%S", tim)


#timezones
tz_LA = pytz.timezone('America/Los_Angeles')
datetime_LA = datetime.now(tz_LA)
print("LA time:", datetime_LA.strftime("%H:%M:%S"))


tz_NY = pytz.timezone('America/New_York')
datetime_NY = datetime.now(tz_NY)
print("NY time:", datetime_NY.strftime("%H:%M:%S"))

tz_London = pytz.timezone('Europe/London')
datetime_London = datetime.now(tz_London)
print("London time:", datetime_London.strftime("%H:%M:%S"))

tz_Paris = pytz.timezone('Europe/Paris')
datetime_Paris = datetime.now(tz_Paris)
print("Paris time:", datetime_Paris.strftime("%H:%M:%S"))
# Out:
# LA time: 11:37:23
# NY time: 14:37:23
# London time: 19:37:23
# Paris time: 20:37:23

# %% [markdown]
# # Configuration

# %%
# start with logs
#-----------------
logging.basicConfig()
logging.root.setLevel(logging.NOTSET)

handle = __name__

logger = logging.getLogger(handle)
# logging.getLogger().setLevel(logging.INFO)
logger.setLevel(logging.DEBUG)

# If you don't want to see log messages from libraries, you can pass a
# specific logger object to the install() function. In this case only log
# messages originating from that logger will show up on the terminal.
coloredlogs.install(level='DEBUG', logger=logger)
coloredlogs.install(fmt='%(asctime)s,%(msecs)03d %(hostname)s %(name)s[%(process)d] %(levelname)s %(message)s')

# %%
# set time
# date
today = date.today()
string_date = today.strftime("%Y-%m-%d")

# time
now = datetime.now()
current_time = now.strftime("%H:%M:%S")

tim = time.localtime()
current_time = time.strftime("%H:%M:%S", tim)

# timezones
tz_LA = pytz.timezone('America/Los_Angeles')
datetime_LA = datetime.now(tz_LA)
msg="LA time:"+  datetime_LA.strftime("%H:%M:%S")
logger.info(msg)

tz_NY = pytz.timezone('America/New_York')
datetime_NY = datetime.now(tz_NY)
msg="NY time:"+ datetime_NY.strftime("%H:%M:%S")
logger.info(msg)

tz_London = pytz.timezone('Europe/London')
datetime_London = datetime.now(tz_London)
msg="London time:"+ datetime_London.strftime("%H:%M:%S")
logger.info(msg)

tz_Paris = pytz.timezone('Europe/Paris')
datetime_Paris = datetime.now(tz_Paris)
msg="Paris time:"+ datetime_Paris.strftime("%H:%M:%S")
logger.info(msg)

msg="************************ START *********************"
logger.info(msg)
# Out:
# 2022-02-19 20:37:23,473 MacBook-Pro-de-admin.local __main__[61649] INFO LA time:11:37:23
# 2022-02-19 20:37:23,474 MacBook-Pro-de-admin.local __main__[61649] INFO NY time:14:37:23
# 2022-02-19 20:37:23,475 MacBook-Pro-de-admin.local __main__[61649] INFO London time:19:37:23
# 2022-02-19 20:37:23,476 MacBook-Pro-de-admin.local __main__[61649] INFO Paris time:20:37:23
# 2022-02-19 20:37:23,477 MacBook-Pro-de-admin.local __main__[61649] INFO ************************ START *********************

# %%
# arguments
#----------

parser = argparse.ArgumentParser()
parser.add_argument("--config",action="store", dest="configfile",help=f" run generate -config configfilename, with by ex configfilename = default.ini")
#results_args = parser.parse_args()

results_args=""

# %%
# config file
# --------------
configfile = "config/default.ini"
#config_filename = results_args.configfile
config_filename = configfile
msg = f"Configuration file : {config_filename}"
logger.info(msg)
# Out:
# 2022-02-19 20:37:23,493 MacBook-Pro-de-admin.local __main__[61649] INFO Configuration file : config/default.ini

# %%
# 1) CONFIGURATION
#------------------
logger.info('1) Configuration')

config = configparser.ConfigParser()

if os.path.exists(config_filename):
    config.read(config_filename)
else:
    msg = f"config file {config_filename} does not exist !"
    logger.error(msg)

config_section = config.sections()
# Out:
# 2022-02-19 20:37:23,501 MacBook-Pro-de-admin.local __main__[61649] INFO 1) Configuration

# %%
if len(config_section) == 0:
    msg = f"empty config file {config_filename} !"
    logger.error(msg)

# %%
if 'GENERAL' in config_section:

    FLAG_DEBUG = bool(int(config['GENERAL']['FLAG_DEBUG']))
    FLAG_VERBOSE = bool(int(config['GENERAL']['FLAG_VERBOSE']))
    FLAG_PLOT = bool(int(config['GENERAL']['FLAG_PLOT']))
    FLAG_PRINT = bool(int(config['GENERAL']['FLAG_PRINT']))
    
    
    NPOINTSVIEW = int(config['GENERAL']['NPOINTSVIEW'])
    NPOINTSSAVE = int(config['GENERAL']['NPOINTSSAVE'])
    
    
else:
    msg = f"Configuration file : empty section GENERAL in config file {config_filename} !"   
    logger.error(msg)


if 'MLFIT'in config_section:
    input_file = config['MLFIT']['inputfile']
    input_dir = config['MLFIT']['inputdir']

    packetsize = int(config['MLFIT']['packetsize'])
    maxnbpacket = int(config['MLFIT']['maxnbpacket'])

    input_file_split=input_file.split(".")    
    basefilename=input_file_split[0]
    extendfilename=input_file_split[1]
else:
    msg="Configuration file : Missing section MLFIT in config file {config_filename} !"
    logger.error(msg)

# %% [markdown]
# # Atmospheric transparency file and selection

# %%
all_files = os.listdir(input_dir)
sorted_files=sorted(all_files)

# %%
# search string
search_str="^"+f"{basefilename}.*fits$"

# %%
selected_files=[]
for file in sorted_files:
    if re.search(search_str,file):
        selected_files.append(file)

# %% [markdown]
# ### Keep a limited number of input files

# %%
if maxnbpacket>0:
    selected_files=selected_files[:maxnbpacket]

# %%
NFiles=len(selected_files)

# %% [markdown]
# # Read simulated atmospheric transparency

# %%
wl,datain,idx_num,idx_am,idx_vaod,idx_pwv,idx_o3,idx_cld,idx_res,header=GetAtmTransparency(input_dir,selected_files)

# %%
logger.info(header)
# Out:
# 2022-02-19 20:37:23,837 MacBook-Pro-de-admin.local __main__[61649] INFO SIMPLE  =                    T / conforms to FITS standard                      BITPIX  =                  -64 / array data type                                NAXIS   =                    2 / number of array dimensions                     NAXIS1  =                  957                                                  NAXIS2  =                  101                                                  NBATMSIM=                20000                                                  ID_NUM  =                    0                                                  ID_AM   =                    1                                                  ID_VAOD =                    2                                                  ID_PWV  =                    3                                                  ID_O3   =                    4                                                  ID_CLD  =                    5                                                  ID_RES  =                    6                                                  END

# %%
num=datain[0:,idx_num]
airmass=datain[0:,idx_am]
vaod=datain[0:,idx_vaod] # vertical aerosol depth
pwv=datain[0:,idx_pwv]   # precipitable water vapor (mm)
ozone=datain[0:,idx_o3]     # ozone
cld=datain[0:,idx_cld]   # clouds (not us

# %%
transm=datain[:,idx_res:]

# %%
def GetDistribFromName(name):
    """
    
    GetDistribFromName(name): Get distribution from name in config file
    
    input arg:
    
    - name : string name of the distribution
    
    """
    
    rayleigh,beta,gamma,uniform
    
    if name=="rayleigh":
        return rayleigh
    elif name=="beta":
        return beta
    elif name=="gamma":
        return gamma
    else:
        return uniform
    


if FLAG_PLOT:
    fig=plt.figure(figsize=(20,10))
    ax1=fig.add_subplot(231)
    ax2=fig.add_subplot(232)
    ax3=fig.add_subplot(233)
    ax4=fig.add_subplot(234)
    ax5=fig.add_subplot(235)
    #ax6=fig.add_subplot(326)

    # -----------------  airmass
    mu=np.average(airmass)
    sigma=np.std(airmass)
    ax1.hist(airmass,bins=50,facecolor='blue',alpha=0.2,density=True);
    ax1.set_title("airmass")
    ax1.set_xlabel("z")
    textstr = '\n'.join((
    r'$\mu=%.2f$' % (mu, ),
    r'$\sigma=%.2f$' % (sigma, )))


    props = dict(boxstyle='round', facecolor='white', alpha=0.5)

    # place a text box in upper left in axes coords
    ax1.text(0.75, 0.8, textstr, transform=ax1.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)

    
    
    if 'AIRMASS' in config_section:
        distrib_name= config['AIRMASS']['distrib']
        distrib=GetDistribFromName(distrib_name)
        # fit dist to data
        params = distrib.fit(airmass)

        # Separate parts of parameters
        arg = params[:-2]
        loc = params[-2]
        scale = params[-1]

        # Calculate fitted PDF and error with fit in distribution
        x=np.linspace(airmass.min(),airmass.max(),100)
        pdf = distrib.pdf(x, loc=loc, scale=scale, *arg)
        label=distrib_name + " : a={:2.2f} b={:2.2f} s={:2.2f}".format(arg[0],arg[1],scale)
        #label=distrib_name + " : s={:2.2f}".format(scale)
        ax1.plot(x,pdf,"r-",label=label)
        ax1.legend()
        ax1.grid()
    
    #----------------pwv--------------------
    
    mu=np.average(pwv)
    sigma=np.std(pwv)
    textstr = '\n'.join((
    r'$\mu=%.2f$' % (mu, ),
    r'$\sigma=%.2f$' % (sigma, )))
    props = dict(boxstyle='round', facecolor='white', alpha=0.5)
    
    ax2.hist(pwv,bins=50,facecolor='blue',alpha=0.2,density=True);
    ax2.set_title("precipitable water vapor")
    ax2.set_xlabel("pwv (mm)")
    
    ax2.text(0.75, 0.8, textstr, transform=ax2.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)
    
    if 'PWV' in config_section:
        distrib_name= config['PWV']['distrib']
        distrib=GetDistribFromName(distrib_name)
        # fit dist to data
        params = distrib.fit(pwv)

        # Separate parts of parameters
        arg = params[:-2]
        loc = params[-2]
        scale = params[-1]

        # Calculate fitted PDF and error with fit in distribution
        x=np.linspace(pwv.min(),pwv.max(),100)
        pdf = distrib.pdf(x, loc=loc, scale=scale, *arg)
        #label=distrib_name + " : s={:2.2f}".format(scale)
        label=distrib_name + " : a={:2.2f} b={:2.2f} s={:2.2f}".format(arg[0],arg[1],scale)
        ax2.plot(x,pdf,"r-",label=label)
        ax2.legend()
        ax2.grid()
    
        
    #-------------- Ozone
    
    mu=np.average(ozone)
    sigma=np.std(ozone)
    textstr = '\n'.join((
    r'$\mu=%.2f$' % (mu, ),
    r'$\sigma=%.2f$' % (sigma, )))
    props = dict(boxstyle='round', facecolor='white', alpha=0.5)
    
    ax3.hist(ozone,bins=50,facecolor='blue',alpha=0.2,density=True);
    ax3.set_title("ozone")
    ax3.set_xlabel("Ozone (DbU)")
    
    ax3.text(0.75, 0.8, textstr, transform=ax3.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)
    
    
    if 'OZONE' in config_section:
        distrib_name= config['OZONE']['distrib']
        distrib=GetDistribFromName(distrib_name)
        # fit dist to data
        params = distrib.fit(ozone)

        # Separate parts of parameters
        arg = params[:-2]
        loc = params[-2]
        scale = params[-1]

        # Calculate fitted PDF and error with fit in distribution
        x=np.linspace(ozone.min(),ozone.max(),100)
        pdf = distrib.pdf(x, loc=loc, scale=scale, *arg)
        #label=distrib_name + " : s={:2.2f}".format(scale)
        label=distrib_name + " : a={:2.2f} b={:2.2f} s={:2.2f}".format(arg[0],arg[1],scale)
        ax3.plot(x,pdf,"r-",label=label)
        ax3.legend()
        ax3.grid()
    
    
    #-------------------- VAOD
    
    mu=np.average(vaod)
    sigma=np.std(vaod)
    textstr = '\n'.join((
    r'$\mu=%.2f$' % (mu, ),
    r'$\sigma=%.2f$' % (sigma, )))
    props = dict(boxstyle='round', facecolor='white', alpha=0.5)
    
    ax4.hist(vaod,bins=50,facecolor='blue',alpha=0.2,density=True);
    ax4.set_title("Aerosols")
    ax4.set_xlabel("vaod")
    
    ax4.text(0.75, 0.8, textstr, transform=ax4.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)
    
    
    if 'AEROSOL' in config_section:
        distrib_name= config['AEROSOL']['distrib']
        distrib=GetDistribFromName(distrib_name)
        # fit dist to data
        params = distrib.fit(vaod)

        # Separate parts of parameters
        arg = params[:-2]
        loc = params[-2]
        scale = params[-1]

        # Calculate fitted PDF and error with fit in distribution
        x=np.linspace(vaod.min(),vaod.max(),100)
        pdf = distrib.pdf(x, loc=loc, scale=scale, *arg)
        #label=distrib_name + " : s={:2.2f}".format(scale)
        label=distrib_name + " : s={:2.2f}".format(scale)
        ax4.plot(x,pdf,"r-",label=label)
        ax4.legend()
        ax4.grid()
    
    #-------------- clouds
    
    mu=np.average(cld)
    sigma=np.std(cld)
    textstr = '\n'.join((
    r'$\mu=%.2f$' % (mu, ),
    r'$\sigma=%.2f$' % (sigma, )))
    props = dict(boxstyle='round', facecolor='white', alpha=0.5)
    
    
    ax5.hist(cld,bins=50,facecolor='blue',alpha=0.2,density=True);
    ax5.set_title("Cloud")
    ax5.set_xlabel("od")
    
    ax5.text(0.75, 0.8, textstr, transform=ax5.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)
    
    
    if 'CLOUD' in config_section:
        distrib_name= config['CLOUD']['distrib']
        distrib=GetDistribFromName(distrib_name)
        # fit dist to data
        params = distrib.fit(cld)

        # Separate parts of parameters
        arg = params[:-2]
        loc = params[-2]
        scale = params[-1]

        # Calculate fitted PDF and error with fit in distribution
        x=np.linspace(cld.min(),cld.max(),100)
        pdf = distrib.pdf(x, loc=loc, scale=scale, *arg)
        #label=distrib_name + " : s={:2.2f}".format(scale)
        label=distrib_name + " : s={:2.2f}".format(scale)
        #ax5.plot(x,pdf,"r-",label=label)
        ax5.legend()
        ax5.grid()
        
        
    plt.tight_layout()
# Out:
# /Users/dagoret/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:621: RuntimeWarning: invalid value encountered in sqrt
#   sk = 2*(b-a)*np.sqrt(a + b + 1) / (a + b + 2) / np.sqrt(a*b)
# 2022-02-19 20:37:25,084 MacBook-Pro-de-admin.local matplotlib.legend[61649] WARNING No handles with labels found to put in legend.

# %% [markdown]
# # Select a Photometric night

# %%
Nobs=200
vaodmean = 0.05
pwvmean = 5.0
ozmean= 300.

# %%
textstr = '\n'.join((
    r'photometric night',
    r'$N_{obs}=%.0f$' % (Nobs,),
    r'$\mathrm{vaod}=%.2f$' % (vaodmean, ),
    r'$\mathrm{pwv}=%.1f$ mm' % (pwvmean, ),
    r'$\mathrm{ozone}=%.1f$ DU' % (ozmean, )))

# %%
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)

# %%
Nobs=200

# %%
indexes_vaod005= np.where(np.logical_and(vaod>vaodmean-0.005,vaod<vaodmean+0.05))[0]

# %%
indexes_pwv005= np.where(np.logical_and(pwv>pwvmean-0.5,pwv<pwvmean+0.5))[0]

# %%
indexes_pwv005
# Out:
# array([   9,   30,   33, ..., 9992, 9994, 9996])

# %%
indexes_selected=np.union1d(indexes_vaod005, indexes_pwv005)

# %%
indexes_oz300= np.where(np.logical_and(ozone>ozmean-10,ozone<ozmean+10))[0]

# %%
indexes_selected = np.union1d(indexes_selected,indexes_oz300)

# %%
N=len(indexes_selected)
N
# Out:
# 6180

# %%
# sample randomly a subsample
indexes_selected = np.random.choice(indexes_selected , size=Nobs, replace=False)

# %%
num=num[indexes_selected]
airmass=airmass[indexes_selected]
vaod=vaod[indexes_selected] 
pwv=pwv[indexes_selected] 
ozone=ozone[indexes_selected]   
cld=cld[indexes_selected]  # clouds (not us

# %%
transm=transm[indexes_selected,:]

# %% [markdown]
# ## Select wavelength range
#
# Truncate wavelength

# %%
WLMINSEL=340.
WLMAXSEL=1100.

# %%
indexes_selected=np.where(np.logical_and(wl>=WLMINSEL,wl<=WLMAXSEL))[0]

# %%
# need even number of bins
if len(indexes_selected)%2:
    indexes_selected=indexes_selected[:-1]

# %%
wl=wl[indexes_selected]
transm_tot=transm[:,indexes_selected]

# %%
transm=transm_tot

# %%
def PlotAtm(N=20,ax=None,FLAG_PLOT=True):
    
    if FLAG_PLOT:
    
        jet = plt.get_cmap('jet')
        cNorm = colors.Normalize(vmin=0, vmax=N)
        scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)
        all_colors = scalarMap.to_rgba(np.arange(N), alpha=1)
        
        if ax == None:

            fig=plt.figure(figsize=(10,3))
            ax = fig.add_subplot(111)
            
        for idx in np.arange(N):
            ax.plot(wl,transm[idx,:],c=all_colors[idx])
        ax.set_xlabel("$\lambda$ (nm)")    
        ax.set_title("atmospheric transmissions")

# %%
NWL=wl.shape[0]

# %%
jet = plt.get_cmap('jet')
cNorm = colors.Normalize(vmin=0, vmax=NWL)
scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)
all_colors = scalarMap.to_rgba(np.arange(NWL), alpha=1)

# %% [markdown]
# # Prepare data : X and Y

# %%
airmassarr=airmass[:,np.newaxis]
vaodarr=vaod[:,np.newaxis]
pwvarr=pwv[:,np.newaxis]
o3arr=ozone[:,np.newaxis]
cldarr=cld[:,np.newaxis]

# %% [markdown]
# ## Check atmosphere

# %%
def GetBouguerLinesAtm(Npoints,ax=None,FLAG_PLOT=True):
    """
    """
    wl_sel=np.linspace(350,1000,Npoints)
    wl_label = [ "{:3.0f} nm".format(w) for w in wl_sel]
    iwl_sel=[ find_nearest(wl, wl0)[1] for wl0 in wl_sel ]
    NIWSEL=len(iwl_sel)
    Mags=np.zeros(NIWSEL)
    
    N=NIWSEL
    jet = plt.get_cmap('jet')
    cNorm = colors.Normalize(vmin=0, vmax=N)
    scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)
    all_colors = scalarMap.to_rgba(np.arange(N), alpha=1)
    
    the_x=airmass
    
    
    x_fit=np.linspace(0,the_x.max(),100)
    
    if FLAG_PLOT and ax == None:
        fig=plt.figure(figsize=(12,8))
        ax=fig.add_subplot(111)

    for idx in np.arange(N):
        iwl=iwl_sel[idx]
        if FLAG_CLOUD:
            the_y=-2.5*np.log10(transm[:,iwl]*np.exp(-cld*airmass))
        else:
            the_y=-2.5*np.log10(transm[:,iwl])

        if FLAG_PLOT:
            ax.plot(the_x,the_y,'+',color=all_colors[idx],label=wl_label[idx])
    
        # fit
        popt,cov = np.polyfit(the_x, the_y, 1,cov=True)
        perr=np.sqrt(np.diag(cov))
        nstd=1
        sigmaf=np.sqrt(x_fit**2*cov[0,0]+cov[1,1]+x_fit*(cov[0,1]+cov[1,0]))
        
        Mags[idx]=popt[-1]
        p = np.poly1d(popt)
        
        y_fit=p(x_fit)
        y_fit_up=y_fit+nstd*sigmaf
        y_fit_dw=y_fit-nstd*sigmaf
        
        if FLAG_PLOT:
            ax.plot(x_fit,y_fit,'-',color=all_colors[idx])
            ax.fill_between(x_fit,y_fit_up, y_fit_dw, alpha=.25, color="gray")
    
    
    if FLAG_PLOT:
        ax.legend()
        ax.set_xlim(0,the_x.max())
        #ax.grid()
        ax.set_xlabel("airmass")
        ax.set_ylabel("extinction of atmosphere (mag)")
        ax.set_title("Atmospheric extinction vs airmass")
        
        ax.text(0.15, 0.95, textstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)
        
        #plt.savefig("bouguerlines_photometric.png")
        #plt.show()
     
    return wl_sel,Mags

# %%
FLAG_CLOUD=False
NPOINTSVIEW
GetBouguerLinesAtm(NPOINTSVIEW,ax=None,FLAG_PLOT=True)
# Out:
# (array([ 350.        ,  422.22222222,  494.44444444,  566.66666667,
#          638.88888889,  711.11111111,  783.33333333,  855.55555556,
#          927.77777778, 1000.        ]),
#  array([-0.00949955, -0.00828822, -0.00824862, -0.01195054, -0.00902486,
#         -0.00554152, -0.00447354, -0.00369746,  0.02509037, -0.00285751]))

# %%
NPOINTSVIEW
# Out:
# 10

# %%
def GetBouguerLinesAtmExtrapolation(npoints,ax=None,FLAG_PLOT=True):
    """
    """

    if FLAG_PLOT and ax == None :
        fig=plt.figure(figsize=(12,4))
        ax=fig.add_subplot(111)
    
    
    if FLAG_PLOT:
        label=f"N={npoints}"
        w,m=GetBouguerLinesAtm(npoints,ax=None,FLAG_PLOT=False)
        ax.plot(w,np.power(10,-m/2.5),'o-',color="b",label=label,markersize=4)

   
   
        #ax.grid()
        ax.set_xlabel("$\lambda$ (nm)")
        ax.set_ylabel("Air Transmission")
        ax.set_title("Extrapolated Transmission at null airmass")
    
        #plt.savefig("bouguerlines_extrapolate.png")

# %%
GetBouguerLinesAtmExtrapolation(npoints=100,ax=None,FLAG_PLOT=True)

# %% [markdown]
# ## Combined plots

# %%
fig = plt.figure(figsize=(10, 12), constrained_layout=True)
gs = fig.add_gridspec(3, 1,height_ratios=[1,3,1])


ax0 = fig.add_subplot(gs[0, 0])
PlotAtm(N=20,ax=ax0,FLAG_PLOT=True)


ax1 = fig.add_subplot(gs[1, 0])
GetBouguerLinesAtm(NPOINTSVIEW,ax=ax1,FLAG_PLOT=True)

ax2 = fig.add_subplot(gs[2, 0])
GetBouguerLinesAtmExtrapolation(npoints=100,ax=ax2,FLAG_PLOT=True)

plt.savefig("bouguerlines_atm.png")

# %% [markdown]
# ### concatenate VAOD,PWV, Ozone

# %%
Y=np.concatenate((vaodarr,pwvarr,o3arr,cldarr),axis=1)
Ylabel=["vaod","pwv","ozone","cld"]

# %% [markdown]
# ### Use magnitudes for X

# %%
t=GetListOfCalspec()
t_sel=SelectFewSED(t)

# %%
t_sel
# Out:
# <Table length=8>
#  OBJNAME     RA     DEC   SP_TYPE SP_QUAL ...  calcR   calcI    factor     VmI
#  bytes10  float64 float64 bytes12  bytes1 ... float64 float64  float64   float64
# --------- ------- ------- ------- ------- ... ------- ------- ---------- -------
#   NGC7293 337.411 -20.837   DAO.5       C ...  13.734  14.234      26.01  -0.697
#    G93-48 328.106   2.389   DA2.8       C ...  12.836  13.234      12.34  -0.506
#       HZ4  58.842   9.788   DA3.4       C ...  14.569  14.723     61.551  -0.250
# ALPHA_LYR 279.235  38.784    A0Va       C ...   0.000  -0.004 0.00010079   0.013
#  HD163466 268.106  60.396      A2       E ...   6.694   6.589   0.054409   0.251
#  HD074000 130.212 -16.345      F2       D ...   9.269   8.987    0.72107   0.658
#  HD106252 183.373  10.042      G0       E ...   6.957   6.653   0.091453   0.750
#      FLAT   0.000   0.000    flat       0 ...   9.501   9.001          1   0.999

# %% [markdown]
# ### Show examples of SED to use

# %%
if FLAG_PLOT:
    fig=plt.figure(figsize=(12,5))
    ax=fig.add_subplot(111)
    plot_sed(t_sel,ax)
    plt.show()
# Out:
# WARNING: VerifyWarning: Invalid keyword for column 1: Column disp option (TDISPn) failed verification: Format 26A is not recognized. The invalid value will be ignored for the purpose of formatting the data in this column. [astropy.io.fits.column]
# 2022-02-19 20:37:30,067 MacBook-Pro-de-admin.local astropy[61649] WARNING VerifyWarning: Invalid keyword for column 1: Column disp option (TDISPn) failed verification: Format 26A is not recognized. The invalid value will be ignored for the purpose of formatting the data in this column.
# WARNING: VerifyWarning: Invalid keyword for column 2: Column disp option (TDISPn) failed verification: Format 18A is not recognized. The invalid value will be ignored for the purpose of formatting the data in this column. [astropy.io.fits.column]
# 2022-02-19 20:37:30,074 MacBook-Pro-de-admin.local astropy[61649] WARNING VerifyWarning: Invalid keyword for column 2: Column disp option (TDISPn) failed verification: Format 18A is not recognized. The invalid value will be ignored for the purpose of formatting the data in this column.
# WARNING: VerifyWarning: Invalid keyword for column 3: Column disp option (TDISPn) failed verification: Format 56A is not recognized. The invalid value will be ignored for the purpose of formatting the data in this column. [astropy.io.fits.column]
# 2022-02-19 20:37:30,080 MacBook-Pro-de-admin.local astropy[61649] WARNING VerifyWarning: Invalid keyword for column 3: Column disp option (TDISPn) failed verification: Format 56A is not recognized. The invalid value will be ignored for the purpose of formatting the data in this column.
# WARNING: VerifyWarning: Invalid keyword for column 4: Column disp option (TDISPn) failed verification: Format 68A is not recognized. The invalid value will be ignored for the purpose of formatting the data in this column. [astropy.io.fits.column]
# 2022-02-19 20:37:30,086 MacBook-Pro-de-admin.local astropy[61649] WARNING VerifyWarning: Invalid keyword for column 4: Column disp option (TDISPn) failed verification: Format 68A is not recognized. The invalid value will be ignored for the purpose of formatting the data in this column.
# Warning, 44 of 7210 bins contained negative fluxes; they have been set to zero.
# Warning, 19 of 6265 bins contained negative fluxes; they have been set to zero.

# %% [markdown]
# # Get the Spectra

# %% [markdown]
# ## define the filenames

# %%
idx_sed_sel=3
sed_filename=t_sel[idx_sed_sel]["FILES"]
sed_objname=t_sel[idx_sed_sel]["OBJNAME"]
sed_fullfilename=os.path.join(path_sed_calspec,sed_filename)
############
order2=False
cut=True
############
if order2 and not cut:
    specarrayfile="spec_"+sed_objname+"_ord12_v2.npy"
    specarrayfile2="spec2_"+sed_objname+"_ord2_v2.npy"
    
    specarrayfile3="spec_noatmnoqe_"+sed_objname+"_ord12_v2.npy"
    specarrayfile4="spec2_noatmnoqe_"+sed_objname+"_ord2_v2.npy"
    
    
    title_spec1="spectra order 1 and 2"
    title_spec2="spectra order 2"
    
    title_spec3="spectra order 1 and 2 no atm no qe"
    title_spec4="spectra order 2 no atm no qe"
elif order2 and cut:
    specarrayfile="speccut_"+sed_objname+"_ord12_v2.npy"
    specarrayfile2="spec2cut_"+sed_objname+"_ord2_v2.npy"
    
    specarrayfile3="speccut_noatmnoqe_"+sed_objname+"_ord12_v2.npy"
    specarrayfile4="spec2cut_noatmnoqe_"+sed_objname+"_ord2_v2.npy"
    
    
    title_spec1="spectra order 1 and 2"
    title_spec2="spectra order 2"
    
    title_spec3="spectra order 1 and 2 no atm no qe"
    title_spec4="spectra order 2 no atm no qe"    
    
    
else:
    specarrayfile="spec_"+sed_objname+"_ord1_v2.npy"
    specarrayfile2="spec2_"+sed_objname+"_ord2_v2.npy"
    title_spec1="spectra order 1"
    title_spec2="spectra order 2"
    
    specarrayfile3="spec_noatmnoqe_"+sed_objname+"_ord1_v2.npy"
    specarrayfile4="spec2_noatmnoqe_"+sed_objname+"_ord2_v2.npy"
    
    title_spec1="spectra order 1"
    title_spec2="spectra order 2"
    
    title_spec3="spectra order 1 no atm no qe"
    title_spec4="spectra order 2 no atm no qe"

# %%
specarrayfile
# Out:
# 'spec_ALPHA_LYR_ord1_v2.npy'

# %%
specarrayfile2
# Out:
# 'spec2_ALPHA_LYR_ord2_v2.npy'

# %%
if sed_filename=="flat":
    flatsp = S.FlatSpectrum(10, fluxunits='photlam')
    spec=flatsp
else:
    spec=S.FileSpectrum(sed_fullfilename)
        
spec_norm = spec.renorm(10, 'vegamag', S.ObsBandpass('johnson,v'))   
spec_norm.convert('photlam')

# %% [markdown]
# # Compute Spectra

# %% [markdown]
# ## Compute SED x Tatm x Tholo x Ttelesc

# %%
if not os.path.isfile(specarrayfile) or not os.path.isfile(specarrayfile2) :
    spectra,spectra2=GetSpectra(sed=spec_norm,wl_atm=wl,atm_transmission=transm,order2=order2,cut=cut)
    np.save(specarrayfile,spectra)
    np.save(specarrayfile2,spectra2)   
else:
    spectra=np.load(specarrayfile)
    spectra2=np.load(specarrayfile2)
# Out:
# /Users/dagoret/anaconda3/lib/python3.8/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# 2022-02-19 20:37:30,908 MacBook-Pro-de-admin.local numexpr.utils[61649] INFO NumExpr defaulting to 8 threads.
# (((QE * atm0) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm0) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm1) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm1) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm2) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm2) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm3) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm3) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm4) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm4) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm5) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm5) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm6) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm6) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm7) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm7) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm8) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm8) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm9) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm9) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm10) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm10) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm11) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm11) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm12) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm12) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm13) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm13) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm14) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm14) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm15) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm15) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm16) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm16) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm17) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm17) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm18) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm18) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm19) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm19) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm20) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm20) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm21) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm21) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm22) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm22) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm23) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm23) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm24) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm24) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm25) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm25) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm26) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm26) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm27) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm27) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm28) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm28) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm29) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm29) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm30) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm30) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm31) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm31) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm32) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm32) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm33) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm33) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm34) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm34) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm35) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm35) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm36) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm36) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm37) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm37) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm38) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm38) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm39) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm39) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm40) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm40) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm41) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm41) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm42) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm42) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm43) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm43) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm44) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm44) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm45) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm45) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm46) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm46) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm47) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm47) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm48) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm48) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm49) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm49) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm50) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm50) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm51) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm51) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm52) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm52) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm53) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm53) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm54) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm54) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm55) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm55) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm56) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm56) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm57) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm57) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm58) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm58) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm59) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm59) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm60) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm60) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm61) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm61) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm62) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm62) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm63) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm63) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm64) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm64) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm65) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm65) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm66) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm66) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm67) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm67) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm68) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm68) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm69) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm69) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm70) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm70) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm71) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm71) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm72) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm72) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm73) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm73) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm74) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm74) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm75) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm75) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm76) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm76) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm77) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm77) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm78) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm78) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm79) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm79) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm80) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm80) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm81) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm81) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm82) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm82) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm83) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm83) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm84) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm84) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm85) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm85) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm86) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm86) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm87) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm87) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm88) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm88) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm89) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm89) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm90) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm90) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm91) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm91) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm92) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm92) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm93) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm93) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm94) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm94) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm95) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm95) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm96) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm96) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm97) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm97) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm98) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm98) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm99) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm99) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm100) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm100) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm101) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm101) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm102) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm102) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm103) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm103) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm104) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm104) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm105) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm105) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm106) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm106) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm107) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm107) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm108) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm108) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm109) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm109) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm110) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm110) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm111) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm111) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm112) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm112) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm113) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm113) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm114) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm114) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm115) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm115) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm116) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm116) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm117) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm117) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm118) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm118) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm119) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm119) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm120) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm120) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm121) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm121) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm122) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm122) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm123) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm123) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm124) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm124) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm125) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm125) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm126) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm126) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm127) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm127) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm128) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm128) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm129) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm129) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm130) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm130) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm131) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm131) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm132) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm132) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm133) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm133) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm134) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm134) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm135) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm135) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm136) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm136) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm137) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm137) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm138) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm138) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm139) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm139) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm140) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm140) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm141) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm141) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm142) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm142) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm143) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm143) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm144) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm144) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm145) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm145) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm146) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm146) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm147) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm147) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm148) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm148) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm149) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm149) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm150) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm150) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm151) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm151) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm152) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm152) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm153) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm153) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm154) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm154) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm155) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm155) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm156) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm156) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm157) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm157) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm158) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm158) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm159) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm159) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm160) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm160) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm161) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm161) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm162) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm162) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm163) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm163) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm164) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm164) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm165) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm165) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm166) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm166) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm167) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm167) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm168) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm168) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm169) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm169) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm170) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm170) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm171) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm171) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm172) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm172) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm173) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm173) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm174) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm174) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm175) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm175) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm176) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm176) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm177) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm177) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm178) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm178) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm179) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm179) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm180) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm180) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm181) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm181) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm182) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm182) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm183) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm183) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm184) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm184) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm185) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm185) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm186) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm186) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm187) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm187) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm188) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm188) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm189) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm189) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm190) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm190) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm191) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm191) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm192) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm192) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm193) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm193) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm194) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm194) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm195) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm195) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm196) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm196) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm197) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm197) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm198) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm198) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm199) * Holo)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (((QE * atm199) * Holo2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.

# %% [markdown]
# ## Compute SED x Tholo

# %%
if not os.path.isfile(specarrayfile3) or not os.path.isfile(specarrayfile4) :
    spectra3,spectra4=GetSpectraNoAtm(sed=spec_norm,wl_atm=wl,atm_transmission=transm,order2=order2,cut=cut)
    np.save(specarrayfile3,spectra3)
    np.save(specarrayfile4,spectra4)   
else:
    spectra3=np.load(specarrayfile3)
    spectra4=np.load(specarrayfile4)
# Out:
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (Holo2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.

# %%
if FLAG_PLOT:
    
    N=20
    jet = plt.get_cmap('jet')
    cNorm = colors.Normalize(vmin=0, vmax=N)
    scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)
    all_colors = scalarMap.to_rgba(np.arange(N), alpha=1)
    
    themax=0
    themin=0
    
    fig=plt.figure(figsize=(16,4))
    ax = fig.add_subplot(121)
    for idx in np.arange(N):
        if spectra[idx,:].max()>themax:
            themax=spectra[idx,:].max()
        ax.plot(wl,spectra[idx,:],color=all_colors[idx])
    ax.set_ylim(0,1.1*themax)
    #ax.grid()
    ax.set_xlabel("$\lambda$ (nm)")
    ax.set_ylabel("flux (photlam)")
    ax.set_title(title_spec1)
    
    ax = fig.add_subplot(122)
    for idx in np.arange(N):
        ax.plot(wl,spectra2[idx,:],color=all_colors[idx])
    ax.set_xlabel("$\lambda$ (nm)")
    ax.set_ylabel("flux (photlam)")
    ax.set_ylim(0,1.1*themax)
    ax.set_title(title_spec2)
    #ax.grid()

# %%
def PlotSpectraAndSED(ax=None,FLAG_PLOT=True):
    """
    """ 
    textstr = '\n'.join((
        r'Fluxes :',
        r'$SED \times T^{atm}(\lambda) \times T^{holo}(\lambda) \times T^{telesc} (\lambda)$'))
         
        
    # these are matplotlib.patch.Patch properties
    props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)


    if FLAG_PLOT:
    
        N=20
        jet = plt.get_cmap('jet')
        cNorm = colors.Normalize(vmin=0, vmax=N)
        scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)
        all_colors = scalarMap.to_rgba(np.arange(N), alpha=1)
    
        themax=0
        themin=0
    
        if ax == None:
            fig=plt.figure(figsize=(10,6))
            ax = fig.add_subplot(111)
            
        # loop on spectra    
        for idx in np.arange(N):
            
            if spectra[idx,:].max()>themax:
                themax=spectra[idx,:].max()
                
            ax.plot(wl,spectra[idx,:],color=all_colors[idx])
            
            
        ax.set_ylim(0,1.1*themax)
        #ax.grid()
        ax.set_xlabel("$\lambda$ (nm)")
        ax.set_ylabel("flux (photlam)")
        ax.set_title("Simulated Fluxes and original SED")
        
        ax.text(0.6, 0.95, textstr, transform=ax.transAxes, fontsize=10,verticalalignment='top', bbox=props)
        
        # plot SED
    
        ax2 = ax.twinx()
        wl_2 = spec_norm.wave/10.
        fl_2 = spec_norm.flux*10.
        indexes_2 = np.where(np.logical_and(wl_2>=wl[0],wl_2<wl[-1]))[0]
        ax2.plot(wl_2[indexes_2],fl_2[indexes_2],'k-',label="SED (Vega)")
        
        
        ax2.plot(wl,spectra3[0,:],'r-',label="$SED \, x \, T^{holo}(\lambda)$")
        ax2.legend(loc = "lower right")

# %%
PlotSpectraAndSED(ax=None,FLAG_PLOT=True)

# %%
if FLAG_PLOT:
    
    N=20
    jet = plt.get_cmap('jet')
    cNorm = colors.Normalize(vmin=0, vmax=N)
    scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)
    all_colors = scalarMap.to_rgba(np.arange(N), alpha=1)
    
    themax=0
    themin=0
    
    fig=plt.figure(figsize=(16,4))
    ax = fig.add_subplot(121)
    for idx in np.arange(N):
        if spectra3[idx,:].max()>themax:
            themax=spectra3[idx,:].max()
        ax.plot(wl,spectra3[idx,:],color=all_colors[idx])
    ax.set_ylim(0,1.1*themax)
    ax.grid()
    ax.set_xlabel("$\lambda$ (nm)")
    ax.set_title(title_spec3)
    
    ax = fig.add_subplot(122)
    for idx in np.arange(N):
        ax.plot(wl,spectra4[idx,:],color=all_colors[idx])
    ax.set_xlabel("$\lambda$ (nm)")
    ax.set_ylim(0,1.1*themax)
    ax.set_title(title_spec4)
    ax.grid()

# %%
X=-2.5*(np.log10(spectra)-np.log10(spectra3))

# %% [markdown]
# ### Check transmission or spectrum

# %%
if FLAG_PLOT:
    N=50
    jet = plt.get_cmap('jet')
    cNorm = colors.Normalize(vmin=0, vmax=N)
    scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)
    all_colors = scalarMap.to_rgba(np.arange(N), alpha=1)


    fig=plt.figure(figsize=(10,5))
    ax = fig.add_subplot(111)
    for idx in np.arange(N):
        ax.plot(wl,X[idx,:],color=all_colors[idx])
    ax.set_xlabel("$\lambda$ (nm)")
    ax.set_ylabel("mag")
    ax.set_title("X = Spectra/(SED x Holo Transmission) = Tatm x Telescope Transm ")
    ax.grid()
    ax1 = ax.twinx()
    ax1.set_ylim(ax.get_ylim())

# %% [markdown]
# # Bouguer Lines

# %%
def GetBouguerLines(Npoints,ax=None,FLAG_PLOT=True):
    """
    """
    wl_sel=np.linspace(350,1000,Npoints)
    wl_label = [ "{:3.0f} nm".format(w) for w in wl_sel]
    iwl_sel=[ find_nearest(wl, wl0)[1] for wl0 in wl_sel ]
    NIWSEL=len(iwl_sel)
    Mags=np.zeros(NIWSEL)
    
    N=NIWSEL
    jet = plt.get_cmap('jet')
    cNorm = colors.Normalize(vmin=0, vmax=N)
    scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)
    all_colors = scalarMap.to_rgba(np.arange(N), alpha=1)
    
    the_x=airmass
    the_y=X[:,iwl_sel]  # spectra
    
    
    
    x_fit=np.linspace(0,the_x.max(),100)
    
    if FLAG_PLOT:
        if ax == None:
            fig=plt.figure(figsize=(12,8))
            ax=fig.add_subplot(111)

    for idx in np.arange(N):
        iwl=iwl_sel[idx]
        the_y=X[:,iwl]

        if FLAG_PLOT:
            ax.plot(the_x,the_y,'+',color=all_colors[idx],label=wl_label[idx])
    
       
        # fit
        popt,cov = np.polyfit(the_x, the_y, 1,cov=True)
        perr=np.sqrt(np.diag(cov))
        nstd=1
        sigmaf=np.sqrt(x_fit**2*cov[0,0]+cov[1,1]+x_fit*(cov[0,1]+cov[1,0]))
        
        Mags[idx]=popt[-1]
        p = np.poly1d(popt)
        
        y_fit=p(x_fit)
        y_fit_up=y_fit+nstd*sigmaf
        y_fit_dw=y_fit-nstd*sigmaf
        
        if FLAG_PLOT:
            ax.plot(x_fit,y_fit,'-',color=all_colors[idx])
            ax.fill_between(x_fit,y_fit_up, y_fit_dw, alpha=.5, color="gray")
    
    
    if FLAG_PLOT:
        ax.legend()
        ax.set_xlim(0,the_x.max())
        #ax.grid()
        ax.set_xlabel("airmass")
        ax.set_ylabel("magnitude (mag)")
        ax.set_title("$Flux/(SED \, \\times  T^{holo}) \;= \; T^{atm} \\times T^{telesc}$")
        #plt.show()
    
    
    
    return wl_sel,Mags

# %%
w10,m10=GetBouguerLines(NPOINTSVIEW,ax=None,FLAG_PLOT=True)

# %%
# quantum efficiency
wl_ccd,throughput,ccdqe,trans_opt_elec=lsst.GetThroughputAndCCDQE("../../data/lsst")
# Out:
# /Users/dagoret/anaconda3/lib/python3.8/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
def GetBouguerLinesExtrapolation(npoints,ax=None,FLAG_PLOT=True):
    """
    """
    
    if FLAG_PLOT:
        if ax == None:
            fig=plt.figure(figsize=(15,9))
            ax=fig.add_subplot(1,1,1)
            
        
        label=f"N={npoints}"
        w,m=GetBouguerLines(npoints,ax=ax,FLAG_PLOT=False)
        
        ax.plot(w,np.power(10,-m/2.5),'o-',color=all_colors[idx],label="extrapolated Bouguer line at z=0")
        
        ax.plot(wl_ccd,ccdqe,'k-',label="Simulated telescope throughput")
        
        ax.legend()
        #ax.grid()
        ax.set_xlabel("$\lambda$ (nm)")
        ax.set_ylabel("Instrument transmission")
        ax.set_title("Extrapolation of Bouguer lines : Telescope throughput $T^{telesc}$")

# %%
GetBouguerLinesExtrapolation(npoints=100,ax=None,FLAG_PLOT=True)

# %%
if FLAG_PLOT:
    fig=plt.figure(figsize=(15,9))
    
    gs = fig.add_gridspec(2, 1,height_ratios=[3,1])
   
    
    #ax=fig.add_subplot(211)
    ax=fig.add_subplot(gs[0, :])
    
    ax.plot(wl_ccd,ccdqe,'o-k',label="QE sim")
    
    NPOINTS=np.arange(10,80,10)
    NNPOINTS=len(NPOINTS)
    
    N=NNPOINTS
    jet = plt.get_cmap('jet')
    cNorm = colors.Normalize(vmin=0, vmax=N)
    scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)
    all_colors = scalarMap.to_rgba(np.arange(N), alpha=1)
    
    for idx in np.arange(NNPOINTS):
        npoints=NPOINTS[idx]
        label=f"N={npoints}"
        w,m=GetBouguerLines(npoints,ax=ax,FLAG_PLOT=False)
        
        ax.plot(w,np.power(10,-m/2.5),'o-',color=all_colors[idx],label=label)

   
    ax.legend()
    ax.grid()
    #ax.set_xlabel("$\lambda$ (nm)")
    ax.set_ylabel("Instrument transmission")
    ax.set_title("Estimation of Instrument transmission")
    
    
   
   
    
    #ax2=fig.add_subplot(212)
    ax2=fig.add_subplot(gs[1, :])
    
    for idx in np.arange(NNPOINTS):
        npoints=NPOINTS[idx]
        label=f"N={npoints}"
        w,m=GetBouguerLines(npoints,ax=ax2,FLAG_PLOT=False)
        
        func_ccd = interpolate.interp1d(wl_ccd, ccdqe)
        fccd=func_ccd(w)
        
        ax2.plot(w,np.power(10,-m/2.5)/fccd,'o-',color=all_colors[idx],label=label)

   
    #ax2.legend()
    ax2.grid()
    ax2.set_xlabel("$\lambda$ (nm)")
    ax2.set_ylabel("transmission ratio")
    #ax.set_title("Estimation of Instrument transmission")
    ax.get_shared_x_axes().join(ax, ax2)
    ax.set_xticklabels([])
    #ax2.set_ylim(0.9,1.1)
    
    plt.tight_layout()

# %%
fig = plt.figure(figsize=(10, 12), constrained_layout=True)
gs = fig.add_gridspec(3, 1,height_ratios=[1,3,1])



ax0 = fig.add_subplot(gs[0, 0])
PlotSpectraAndSED(ax=ax0,FLAG_PLOT=True)

ax1 = fig.add_subplot(gs[1, 0])
w10,m10=GetBouguerLines(NPOINTSVIEW,ax=ax1,FLAG_PLOT=True)

ax2 = fig.add_subplot(gs[2, 0])
GetBouguerLinesExtrapolation(npoints=100,ax=ax2,FLAG_PLOT=True)

plt.savefig("bouguerlines_throughput.png")
